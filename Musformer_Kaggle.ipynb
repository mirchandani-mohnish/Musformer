# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/musdb18-music-source-separation-dataset/The Long Wait - Dark Horses.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Raft Monk - Tiring.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/BKS - Too Much.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Georgia Wonder - Siren.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/The Sunshine Garcia Band - For I Am The Moon.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Enda Reilly - Cur An Long Ag Seol.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Buitraker - Revo X.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/We Fell From The Sky - Not You.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/The Mountaineering Club - Mallory.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Skelpolu - Resurrection.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Secretariat - Over The Top.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Bobby Nobody - Stitch Up.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Arise - Run Run Run.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Carlos Gonzalez - A Place For Us.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Forkupines - Semantics.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/The Easton Ellises - Falcon 69.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Lyndsey Ollard - Catching Up.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Triviul feat. The Fiend - Widow.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Louis Cressy Band - Good Time.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Motor Tapes - Shore.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/AM Contra - Heart Peripheral.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Signe Jakobsen - What Have You Done To Me.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Moosmusic - Big Dummy Shake.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/M.E.R.C. Music - Knockout.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/The Doppler Shift - Atrophy.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Detsky Sad - Walkie Talkie.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/PR - Happy Daze.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Timboz - Pony.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/PR - Oh No.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Mu - Too Bright.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Hollow Ground - Ill Fate.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/The Easton Ellises (Baumi) - SDRNR.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Speak Softly - Like Horses.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Sambasevam Shanmugam - Kaathaadi.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Tom McKenzie - Directions.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Secretariat - Borderline.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Side Effects Project - Sing With Me.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Nerve 9 - Pray For The Rain.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Zeno - Signs.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Girls Under Glass - We Feel Alright.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Cristina Vane - So Easy.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Speak Softly - Broken Man.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/BKS - Bulldozer.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Punkdisco - Oral Hygiene.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/test/Al James - Schoolboy Facination.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Dark Ride - Burning Bridges.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Drumtracks - Ghost Bitch.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Aimee Norwich - Child.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/James May - If You Say.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Rockabilly.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Steven Clark - Bounty.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Giselle - Moss.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Strand Of Oaks - Spacestation.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Patrick Talbot - Set Me Free.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Bill Chudziak - Children Of No-one.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Angela Thomas Wade - Milk Cow Blues.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Grants - PunchDrunk.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Grunge.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Traffic Experiment - Once More (With Feeling).stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Beatles.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Auctioneer - Our Future Faces.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Clara Berry And Wooldog - Air Traffic.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Patrick Talbot - A Reason To Leave.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/The Districts - Vermont.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Leaf - Come Around.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/North To Alaska - All The Same.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Skelpolu - Human Mistakes.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Dreamers Of The Ghetto - Heavy Love.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/ANiMAL - Rockshow.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Faces On Film - Waiting For Ga.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Snowmine - Curfews.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Swinging Steaks - Lost My Way.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Triviul - Dorothy.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Gospel.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Clara Berry And Wooldog - Stella.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Disco.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Reggae.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/The So So Glos - Emergency.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Leaf - Wicked.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/St Vitus - Word Gets Around.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Celestial Shore - Die For Us.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Young Griffo - Facade.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/AvaLuna - Waterduct.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Punk.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Actions - One Minute Smile.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Young Griffo - Blood To Bone.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Tim Taler - Stalker.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Hendrix.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Leaf - Summerghost.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Hop Along - Sister Cities.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/James May - All Souls Moon.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Meaxic - You Listen.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Country2.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/ANiMAL - Clinic A.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Traffic Experiment - Sirens.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Britpop.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Rock.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Chris Durban - Celebrate.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Triviul - Angelsaint.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/James May - On The Line.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/A Classic Education - NightOwl.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Skelpolu - Together Alone.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Titanium - Haunted Age.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Alexander Ross - Goodbye Bolero.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Secret Mountains - High Horse.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Wall Of Death - Femme.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Fergessen - The Wind.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Alexander Ross - Velvet Curtain.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Johnny Lokke - Whisper To A Scream.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Meaxic - Take A Step.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Jay Menon - Through My Eyes.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Flags - 54.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Clara Berry And Wooldog - Waltz For My Victims.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/ANiMAL - Easy Tiger.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Fergessen - Back From The Start.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Hollow Ground - Left Blind.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Sweet Lights - You Let Me Down.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Port St Willow - Stay Even.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Helado Negro - Mitad Del Mundo.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Black Bloc - If You Want Success.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Young Griffo - Pennies.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Voelund - Comfort Lives In Belief.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Fergessen - Nos Palpitants.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Creepoid - OldTree.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Actions - South Of The Water.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Lushlife - Toynbee Suite.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Matthew Entwistle - Dont You Ever.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/The Scarlet Brand - Les Fleurs Du Mal.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - Country1.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/James May - Dont Let Go.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Music Delta - 80s Rock.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Atlantis Bound - It Was My Fault For Waiting.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Invisible Familiars - Disturbing Wildlife.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Cnoc An Tursa - Bannockburn.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Hezekiah Jones - Borrowed Heart.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/BigTroubles - Phantom.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Remember December - C U Next Time.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/Night Panther - Fire.stem.mp4
# /kaggle/input/musdb18-music-source-separation-dataset/train/The Long Wait - Back Home To Blue.stem.mp4

# %% [markdown]
# ## Musformer
# Although misleading, but the name seemed nice. The goal of this project is to try out multiple source separation models in speechbrain. The idea is to replicate building a model in the waveform domain directly. We see that multiple models try to solve the music sourse separation as a problem and most state-of-the-art models reach an SiSDR ratio of 9 to tackle the same.
#
# Most models working on this problem came into existence as a solution to the SDX (Sound Demixing) challenge. A few of the existing solutions are as follows:
# - **MMDenseLSTM**: Combines dense blocks with LSTMs for lightweight waveform separation.
# - **Demucs (v1/v2)**: U-Net with bidirectional LSTMs; later versions add transformers.
# - **ConvTasNet**: Efficient temporal convolutional network with learned encoder/decoder.
# - **DPRNNet**: Dual-path RNN with attention, offering SOTA results at higher compute costs.
# - **BandSplitRNN**: Separates audio into frequency bands processed by independent RNNs before recombination.
# - **Wave-U-Net**: Adapts medical imaging's U-Net architecture for waveform-based source separation with learned down/upsampling.
# - **Open-Unmix**: Spectrogram-based separation model using three-layer BiLSTMs with industry-standard implementation.
# - **ResUNetDecouple**: U-Net variant with residual connections that decouples magnitude and phase processing.
# - **TDCN++**: Improved temporal convolutional network with global skip connections and stacked dilation patterns.
# - **Spleeter**: Facebook's lightweight CNN-based separator using spectrogram masking with pretrained models.
#
# Our goal in this mini-project is to focus on the waveform domain. We try to implement four of these in their basest versions in order to learn how these architectures come into life for vocal separation from music. Along with that, we use multiple attempts to enhance our working.
#
# This is a project done by Mohnish Mirchandani, under professor Mirco Ravanelli, at Concordia University

# %% [markdown]
# ## Disclaimers
# This notebook refers to the tip of the iceberg of multiple approaches tried along the way in order to reach here. It provides for a summary of the underlying work done around trials and errors in speech separation. More about the same is appended in the Archives section at the end of this report notebook. Additionally, the informal nature of the text in this report is to keep the content somewhat light-hearted in order to ensure engagement with the reader...
#
#
# This report is intended to be self explanatory and so all the data you need to learn about these models should be referenced in the report itself. Additionally, all the models presented here have their intended recipes which you can use to cook your own models...
#
# Bonne Apetit!

# %% [markdown]
# ## Step1 : Gaining Context (Literature Review)
#
# ### Gimme the Data!!
# First things first, lets talk about the dataset and the models a bit. MUSDB18 is the benchmark dataset for music source separation, containing 150 full-track recordings (100 for training, 50 for test) with isolated stems for vocals, drums, bass, and other instruments. It provides professionally mixed 44.1kHz stereo audio, enabling evaluation of waveform-domain separation models. The dataset covers diverse genres and production styles, making it ideal for testing real-world generalization. It has become the standard benchmark for models like Open-Unmix, Demucs, and D3Net, with SI-SDR and SDR as primary metrics. The included Python toolbox (musdb) provides data loading, evaluation, and stem mixing utilities. Musdb is however dependent on something known as STEM files i.e. music tensor files combined and compressed into one. We use the kaggle uploaded version of the dataset which saves us the trouble of downloading, unzipping and uploading the same. You can find the dataset here: https://www.kaggle.com/datasets/jakerr5280/musdb18-music-source-separation-dataset
#
#
# ### The MusDB Package
# One of the most helpful things available in the community to enhance the friendliness of this challenge is the [package provided by sigsep](https://github.com/sigsep/sigsep-mus-db/tree/master/musdb). Given that all the files are STEM format files i.e. a format extension which clubs multiple vectors into a cohesive mp4 format, the musdb package helps us read those using [FFMPEG](https://ffmpeg.org/). This allows us to load the vectors directly into the file without the need of creating a manifest file to read the particular values.

# %% [markdown]
# ## Step 2: Installing Stuff and Basic Setup
#
# Ugghh... this is the boring part, but thats what makes the fun part funn! So we start by installing the necessary requirements for the entire project, as well as some global variables
#
# The following are the use cases
# - Musdb: Our python package wrapper which helps us iterate through the dataset
# - mir_eval and museval: progressively used to check the sdri scores across models. These are the standard packages used in the MDX challenge as well.
# - Speechbrain (Duhh... obviously)
#
# Additionally, we set certain variables namely:
# - db_path: The path to the dataset
# - output_path: The working directory
# - result_file_path: The file path for the metrics to be provided (Not really needed but thats where you see the magic)
#
# We then create the `result_file` if needed and additionally setup the musdb object for global requirement

# %%
# %%capture
# !pip install musdb
# !pip install mir_eval
# !pip install museval

# Installing SpeechBrain via pip
BRANCH = 'develop'
# !python -m pip install git+https://github.com/speechbrain/speechbrain.git@$BRANCH

# Clone SpeechBrain repository
# !git clone https://github.com/speechbrain/speechbrain/

# %%
db_path = '/kaggle/input/musdb18-music-source-separation-dataset'
output_path = '/kaggle/working'
result_file_path = '/kaggle/working/metrics.csv'

# %%
import csv
from pathlib import Path

def create_metrics_csv(file_path):
    headers = [
        "model_name", "n_epochs", "learning_rate", "chunk_size", "sample_rate", "sdr", "sdr_i", "si-snr", "si-snr_i"
    ]
    
    Path(file_path).parent.mkdir(parents=True, exist_ok=True)

    with open(file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(headers)
    
    print(f"CSV file created successfully at: {file_path}")

if result_file_path is not None:
    create_metrics_csv(result_file_path)
# Out:
# CSV file created successfully at: /kaggle/working/metrics.csv

# %%
import os
import numpy as np
np.float_ = np.float64
import musdb

MUS_DB_PATH = db_path

mus = musdb.DB(root=MUS_DB_PATH)
mus_train = musdb.DB(root=MUS_DB_PATH,subsets="train", split="train")
mus_valid = musdb.DB(root=MUS_DB_PATH,subsets="train", split="valid")
mus_test = musdb.DB(root=MUS_DB_PATH,subsets="test")
print(mus_train[0])
print(mus_test[0])
# Out:
# A Classic Education - NightOwl
# AM Contra - Heart Peripheral

# %% [markdown]
# ## Step 3: Make the Dataset Class
#
# Since music tensors are difficult to load, we use a self made dataset class for our custom dataloader instead of using the DynamicDatasetItems provided by speechbrain. This allows us more flexibility with regard to selecting the tensors at runtime. Due to our prowess with STEM files, we can happily pick up stem chunks rather than taking the entire vocal array to pick up a chunk.
#
#
# This is what we do in the `load_stem_chunk` function. We also pick up some data about the music file in order to use later during the project. (We need a taste of what our recipe makes ;)
#
#
# Musdb inherently gives us a train, valid and test split with 85, 13 and 44 songs respectively. We use the wrapper to decode stem files into their respective chunks and push it to the data pipeline.
# ```
#    # Load only the needed segment
#     audio = source.audio[start:stop]
#
#     # Convert and resample
#     audio_tensor = torch.from_numpy(audio).float().permute(1, 0)
#     return torchaudio.functional.resample(
#         audio_tensor,
#         orig_freq=track_info["rate"],
#         new_freq=self.target_sr
#
# ```
#
# Each music audio is resampled as per the requirement of that specific model run (in the hparams for that model).
#
# We return the following four objects as our dynamic items
# ```
# {
#     "mix_sig": load_stem_chunk("mix", random_chunk_start_val),
#     "voc_sig": load_stem_chunk("vocals",random_chunk_start_val),
#     "inst_sig": load_stem_chunk("accompaniment",random_chunk_start_val),
#     "track_id": track_info["stem_id"]
# }
# ```
#
# Each correspond to their name types. The stem_id is the track name and stem id combined for saving results in the future.

# %%
# %%file dataset.py


import csv
import os
import sys

import torch
import torch.nn.functional as F
import torchaudio
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import musdb
import numpy as np
import speechbrain as sb
import psutil


class MusDBDataset(Dataset):
    def __init__(self, root, subset="train", split=None, target_sr=8000, chunk_size=15):
        """
        True lazy-loading for MUSDB
        :param chunk_size: in seconds
        """
        if split is not None:
            self.db = musdb.DB(root=root, subsets=subset, split=split, is_wav=False)
        else:
            self.db = musdb.DB(root=root, subsets=subset, is_wav=False)
        self.target_sr = target_sr
        self.chunk_size = chunk_size
        self.tracks = [{
            "path": track.path,
            "duration": track.duration,
            "rate": track.rate,
            "stem_id": track.stem_id  # Needed for STEM access
        } for track in self.db.tracks]

    def __len__(self):
        return len(self.tracks)

    def __getitem__(self, idx):
        track_info = self.tracks[idx]
        
        # Load chunk directly from disk without full track loading
        def load_stem_chunk(stem_name, random_chunk_val=0):
            # MUSDB's internal lazy loading
            track = self.db.tracks[idx]
            if stem_name == "mix":
                source = track
            else:
                source = track.targets[stem_name]
            
            # Calculate chunk bounds
            start = random_chunk_val  * track_info["rate"]
            stop = start + self.chunk_size * track_info["rate"]

            max_samples = source.audio.shape[0]  # Total samples in track
            
            # Ensure we don't go beyond track length
            if start >= max_samples:
                start = max(0, max_samples - self.chunk_size * track_info["rate"])
                stop = max_samples
            
            # Load only the needed segment
            audio = source.audio[start:stop]
            
            # Convert and resample
            audio_tensor = torch.from_numpy(audio).float().permute(1, 0)
            return torchaudio.functional.resample(
                audio_tensor,
                orig_freq=track_info["rate"],
                new_freq=self.target_sr
            ).mean(dim=0, keepdim=False)
            
        
            # chunk_size = orig_sr * chunk_size_seconds  # Convert chunk size to samples
        
            # resampled_chunks = []
        
            # for i in range(0, audio_tensor.shape[1], chunk_size):
            #     chunk = audio_tensor[:, i:i + chunk_size]  # Extract chunk
            #     resampled_chunk = torchaudio.functional.resample(chunk, orig_freq=orig_sr, new_freq=target_sr)
            #     resampled_chunks.append(resampled_chunk)
        
            # # Concatenate back the processed chunks
            # # print("PROCESSING CHUNKS")
            # resampled_audio = torch.cat(resampled_chunks, dim=1)
            # # print(resampled_audio.shape)
            # resampled_audio = resampled_audio.mean(dim=0, keepdim=False)
            # # print(resampled_audio.shape)
            # # print(resampled_audio.shape)
            # return resampled_audio
        # if random_chunk_start_val:
        
        random_chunk_start_val = 15
        
        return {
            "mix_sig": load_stem_chunk("mix", random_chunk_start_val),
            "voc_sig": load_stem_chunk("vocals",random_chunk_start_val),
            "inst_sig": load_stem_chunk("accompaniment",random_chunk_start_val),
            "track_id": track_info["stem_id"]
        }
# Out:
# Overwriting dataset.py

# %% [markdown]
# ## How We Doin...? (Methodology)
#
# In order to learn and explore the different model approaches, we draw up each of the available models in speechbrain and try to retrofit them to a simple vocal separation task. The expectation being that the data more often than not, the model is able to reach state-of-the-art...ish levels. The steps we follow are as below:
# 1. Learn and draw up the model architecture using speechbrain modules wherever possible
# 2. Run them on a particular set of data values with particular hyperparameters
# 3. Compare the results

# %% [markdown]
# ## Step 3: The Fun Part (Building the Models)
#
# ### ConvTasNet
# - Key Idea: A fully convolutional, end-to-end waveform model that avoids spectrograms entirely.
# - Encoder-Decoder: Uses 1D convolutions to learn a latent representation of the waveform.
# - Temporal Convolutional Network (TCN): Processes the latent features with stacked dilated convolutions for long-range dependencies.
# - Mask Estimation: Applies a soft mask in the latent space to separate sources.
#
# Advantages:
# - Lightweight and parallelizable (no RNNs).
# - Strong performance on speech and music separation.
#
# Limitations:
# - May struggle with very long-term dependencies due to fixed receptive fields.
#
# Personal Interests:
# Convtasnet proves to be one of the smallest models which generally speaking outperforms most other state-of-the-art models (in the waveform domain). This is intruiging because it uses a simple encoder decoder architecture with a masknet type bottleneck. The version we use in this has 6.6 Million parameters and is successfully able to detach vocals from its accompaniements.
#
# Reference and Sources:
# - https://arxiv.org/abs/1809.07454
# - https://pytorch.org/audio/main/generated/torchaudio.models.ConvTasNet.html
# - https://speechbrain.readthedocs.io/en/latest/API/speechbrain.lobes.models.conv_tasnet.html
# - https://github.com/JusperLee/Conv-TasNet
# - https://github.com/speechbrain/speechbrain/blob/develop/recipes/WSJ0Mix/separation/hparams/convtasnet.yaml
#
#
# #### Architecture
# ![image.png](attachment:21ff3dbb-c8af-4d2e-847a-d97e170eb79f.png)
# source: https://arxiv.org/abs/1809.07454
#
# As can be seen above, we have an encoder, a masknet bottleneck and a decoder block.
#
# The **Encoder** is a simple one dimensional block with a kernel stride of 16. This produces the latent representations for the bottleneck
#
# The **Bottleneck** is a Masknet module again taken from speechbrain. Here is the necessary jargon to understand our implementation
#
# | Parameter  | Meaning                              | Typical Value      | Role                                                                 |
# |------------|--------------------------------------|--------------------|----------------------------------------------------------------------|
# | **`N`**    | Encoder/Decoder filters              | `256`              | Latent representation dimension.                                    |
# | **`B`**    | Bottleneck channels (TCN)            | `256`              | Width of intermediate layers in TCN blocks.                         |
# | **`H`**    | Hidden channels (TCN)                | `512`              | Channels in convolutional layers.                                   |
# | **`P`**    | Kernel size (TCN)                    | `3`                | Temporal span of convolutions (e.g., `3x1`).                        |
# | **`X`**    | Number of TCN stacks                 | `6`                | Repeat blocks for depth (e.g., 6 stacks).                           |
# | **`R`**    | Repeats per stack (TCN)              | `4`                | Dilated convolutional layers per stack (e.g., 4 layers with dilation `1, 2, 4, 8`). |
# | **`C`**    | Number of sources (output masks)     | `!ref <num_sources>` | Matches speakers to separate (e.g., `2` for 2-speaker separation).  |
# | `norm_type`| Normalization type                   | `'gLN'` (Global LayerNorm) | Normalizes across time and channels.                          |
# | `causal`   | Real-time processing                 | `True`             | No future context (set `False` for offline tasks).                  |
# | `mask_nonlinear` | Mask activation                   | `'relu'`           | Ensures non-negative masks.                                         |
#
# Finally, We have a dual path decoder which allows us to reconstruct the waveform from the latent representations. We have most of our values matching that of the encoder

# %%
# %%file convtasnet-hparams.yaml
# # ################################
# # Model: ConvTasNet for Music Vocal Separation
# # https://arxiv.org/abs/2010.13154
# # Dataset : Musdb
# # ################################
# # Basic parameters
# # Seed needs to be set at top of yaml, before objects with parameters are made
#
# seed: 1234
# __set_seed: !apply:speechbrain.utils.seed_everything [!ref <seed>]
#
# ####################### Data Params ########################################
# data_folder: !PLACEHOLDER
#
#
# experiment_name: convtasnet
# output_folder: !ref /kaggle/working/results/<experiment_name>/<seed>
# train_log: !ref <output_folder>/train_log.txt
# save_folder: !ref <output_folder>/save
# train_data: !ref <output_folder>/train.json
# valid_data: !ref <output_folder>/valid.json
# test_data: !ref <output_folder>/test.json
# skip_prep: False
# db_path: '/kaggle/input/musdb18-music-source-separation-dataset'
#
# result_file_path: !PLACEHOLDER
#
#
# # Experiment params
# precision: fp16 # bf16, fp16 or fp32
#
# noprogressbar: False
# save_audio: True # Save estimated sources on disk
# sample_rate: 16000
# n_audio_to_save: 5
# chunk_size: 10
#
#
# ####################### WaveDrop Params ########################################
#
# use_wavedrop: True
# # Frequency drop: randomly drops a number of frequency bands to zero.
# drop_freq_low: 0  # Min frequency band dropout probability
# drop_freq_high: 1  # Max frequency band dropout probability
# drop_freq_count_low: 1  # Min number of frequency bands to drop
# drop_freq_count_high: 3  # Max number of frequency bands to drop
# drop_freq_width: 0.05  # Width of frequency bands to drop
#
# drop_freq: !new:speechbrain.augment.time_domain.DropFreq
#     drop_freq_low: !ref <drop_freq_low>
#     drop_freq_high: !ref <drop_freq_high>
#     drop_freq_count_low: !ref <drop_freq_count_low>
#     drop_freq_count_high: !ref <drop_freq_count_high>
#     drop_freq_width: !ref <drop_freq_width>
#
# # Time drop: randomly drops a number of temporal chunks.
# drop_chunk_count_low: 1  # Min number of audio chunks to drop
# drop_chunk_count_high: 3  # Max number of audio chunks to drop
# drop_chunk_length_low: 1000  # Min length of audio chunks to drop
# drop_chunk_length_high: 2000  # Max length of audio chunks to drop
#
# drop_chunk: !new:speechbrain.augment.time_domain.DropChunk
#     drop_length_low: !ref <drop_chunk_length_low>
#     drop_length_high: !ref <drop_chunk_length_high>
#     drop_count_low: !ref <drop_chunk_count_low>
#     drop_count_high: !ref <drop_chunk_count_high>
#
# ####################### Training Parameters ####################################
# N_epochs: 30
# batch_size: 1
# lr: 0.00015
# clip_grad_norm: 5
# loss_upper_lim: 999999  # this is the upper limit for an acceptable loss
# num_sources: 2
#
#
# # loss thresholding -- this thresholds the training loss
# threshold_byloss: True
# threshold: -30
#
# # Encoder parameters
# N_encoder_out: 256
# # out_channels: 256
# kernel_size: 16
# kernel_stride: 8
#
# # Dataloader options
# dataloader_opts:
#     batch_size: !ref <batch_size>
#     num_workers: 1
#
#
# # Specifying the network
# Encoder: !new:speechbrain.lobes.models.dual_path.Encoder
#     kernel_size: !ref <kernel_size>
#     out_channels: !ref <N_encoder_out>
#
#
# MaskNet: !new:speechbrain.lobes.models.conv_tasnet.MaskNet
#     N: 256
#     B: 256
#     H: 512
#     P: 3
#     X: 6
#     R: 4
#     C: !ref <num_sources>
#     norm_type: 'gLN'
#     causal: True
#     mask_nonlinear: 'relu'
#
#
# Decoder: !new:speechbrain.lobes.models.dual_path.Decoder
#     in_channels: !ref <N_encoder_out>
#     out_channels: 1
#     kernel_size: !ref <kernel_size>
#     stride: !ref <kernel_stride>
#     bias: False
#
# optimizer: !name:torch.optim.Adam
#     lr: !ref <lr>
#     weight_decay: 0
#
# loss: !name:speechbrain.nnet.losses.get_si_snr_with_pitwrapper
#
# lr_scheduler: !new:speechbrain.nnet.schedulers.ReduceLROnPlateau
#     factor: 0.5
#     patience: 2
#     dont_halve_until_epoch: 85
#
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <N_epochs>
#
# modules:
#     encoder: !ref <Encoder>
#     decoder: !ref <Decoder>
#     masknet: !ref <MaskNet>
#
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         encoder: !ref <Encoder>
#         decoder: !ref <Decoder>
#         masknet: !ref <MaskNet>
#         counter: !ref <epoch_counter>
#         lr_scheduler: !ref <lr_scheduler>
#
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
# Out:
# Overwriting convtasnet-hparams.yaml

# %%
# %%file convtasnet-train.py
#!/usr/bin/env/python3
"""
Recipe for vocal separation using convtasnet
"""

import csv
import os
import sys

import numpy as np
import torch
import torch.nn.functional as F
import torchaudio
from hyperpyyaml import load_hyperpyyaml
from tqdm import tqdm
import pdb

import musdb
import torchaudio
import numpy as np
from torch.utils.data import Dataset
import speechbrain as sb
import psutil
from dataset import MusDBDataset


import speechbrain as sb
import speechbrain.nnet.schedulers as schedulers
from speechbrain.core import AMPConfig
from speechbrain.utils.distributed import run_on_main
from speechbrain.utils.logger import get_logger
import time
from torch.utils.data import DataLoader

import musdb


# Define training procedure
class Separation(sb.Brain):
    def compute_forward(self, mix, targets, stage, noise=None):
        """Forward computations from the mixture to the separated signals."""

        # Unpack lists and put tensors in the right device
        mix, mix_lens = mix       
        mix, mix_lens = mix.to(self.device), mix_lens.to(self.device)      

        # Convert targets to tensor
        targets = torch.cat(
            [targets[i][0].unsqueeze(-1) for i in range(self.hparams.num_sources)],
            dim=-1,
        ).to(self.device)

        if stage == sb.Stage.TRAIN:
            with torch.no_grad():
    
                if self.hparams.use_wavedrop:
                    mix = self.hparams.drop_chunk(mix, mix_lens)
                    mix = self.hparams.drop_freq(mix)


        
        # Separation
        mix_w = self.hparams.Encoder(mix)
        est_mask = self.hparams.MaskNet(mix_w)
        mix_w = torch.stack([mix_w] * self.hparams.num_sources)
        sep_h = mix_w * est_mask
        
        # Decoding
        est_source = torch.cat(
            [
                self.hparams.Decoder(sep_h[i]).unsqueeze(-1)
                for i in range(self.hparams.num_sources)
            ],
            dim=-1,
        )

        # pad estimates as per requirement 
        T_origin = mix.size(1)
        T_est = est_source.size(1)
        if T_origin > T_est:
            est_source = F.pad(est_source, (0, 0, 0, T_origin - T_est))
        else:
            est_source = est_source[:, :T_origin, :]

        return est_source, targets

    def compute_objectives(self, predictions, targets):
        """Computes the sinr loss"""
        return self.hparams.loss(targets, predictions)

    def fit_batch(self, batch):
        """Trains one batch"""
        
        
        amp = AMPConfig.from_name(self.precision)
        should_step = (self.step % self.grad_accumulation_factor) == 0
        # Unpacking batch list
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig] #mix_sig, voc_sig, inst_sig
       
        
        predictions, targets = self.compute_forward(
            mixture, targets, sb.Stage.TRAIN
        )
        loss = self.compute_objectives(predictions, targets)

        if self.hparams.threshold_byloss:
            th = self.hparams.threshold
            loss = loss[loss > th]
            if loss.nelement() > 0:
                loss = loss.mean()
        else:
            loss = loss.mean()

        if (
            loss.nelement() > 0 and loss < self.hparams.loss_upper_lim
        ):  # the fix for computational problems
            loss.backward()
            if self.hparams.clip_grad_norm >= 0:
                torch.nn.utils.clip_grad_norm_(
                    self.modules.parameters(),
                    self.hparams.clip_grad_norm,
                )
            self.optimizer.step()
        else:
            self.nonfinite_count += 1
            logger.info(
                "infinite loss or empty loss! it happened {} times so far - skipping this batch".format(
                    self.nonfinite_count
                )
            )
            loss.data = torch.tensor(0.0).to(self.device)
        self.optimizer.zero_grad()

        return loss.detach().cpu()

    def evaluate_batch(self, batch, stage):
        """Computations needed for validation/test batches"""
        snt_id = batch.track_id
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig]

        with torch.no_grad():
            predictions, targets = self.compute_forward(mixture, targets, stage)
            loss = self.compute_objectives(predictions, targets)

        # Manage audio file saving
        if stage == sb.Stage.TEST and self.hparams.save_audio:
            if hasattr(self.hparams, "n_audio_to_save"):
                if self.hparams.n_audio_to_save > 0:
                    self.save_audio(snt_id[0], mixture, targets, predictions)
                    self.hparams.n_audio_to_save += -1
            else:
                self.save_audio(snt_id[0], mixture, targets, predictions)

        return loss.mean().detach()

    def on_stage_end(self, stage, stage_loss, epoch):
        """Gets called at the end of a epoch."""
        # Compute/store important stats
        stage_stats = {"si-snr": stage_loss}
        if stage == sb.Stage.TRAIN:
            self.train_stats = stage_stats

        # Perform end-of-iteration things, like annealing, logging, etc.
        if stage == sb.Stage.VALID:
            # Learning rate annealing
            if isinstance(
                self.hparams.lr_scheduler, schedulers.ReduceLROnPlateau
            ):
                current_lr, next_lr = self.hparams.lr_scheduler(
                    [self.optimizer], epoch, stage_loss
                )
                schedulers.update_learning_rate(self.optimizer, next_lr)
            else:
                # if we do not use the reducelronplateau, we do not change the lr
                current_lr = self.hparams.optimizer.optim.param_groups[0]["lr"]

            self.hparams.train_logger.log_stats(
                stats_meta={"epoch": epoch, "lr": current_lr},
                train_stats=self.train_stats,
                valid_stats=stage_stats,
            )
            self.checkpointer.save_and_keep_only(
                meta={"si-snr": stage_stats["si-snr"]}, min_keys=["si-snr"]
            )
        elif stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                stats_meta={"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stage_stats,
            )



    def save_results(self, test_loader):
        """This script computes the SDR and SI-SNR metrics and saves
        them into a csv file"""

        # This package is required for SDR computation
        from mir_eval.separation import bss_eval_sources

        # Create folders where to store audio
        save_file = os.path.join(self.hparams.output_folder, "test_results.csv")

        # Variable init
        all_sdrs = []
        all_sdrs_i = []
        all_sisnrs = []
        all_sisnrs_i = []
        csv_columns = ["snt_id", "sdr", "sdr_i", "si-snr", "si-snr_i"]


        def is_silent(source, threshold=1e-6):
            return np.max(np.abs(source[0])) < threshold or np.max(np.abs(source[1])) < threshold

        with open(save_file, "w", newline="", encoding="utf-8") as results_csv:
            writer = csv.DictWriter(results_csv, fieldnames=csv_columns)
            writer.writeheader()
            skip_cnt = 0

            # Loop over all test sentence
            with tqdm(test_loader, dynamic_ncols=True) as t:
                for i, batch in enumerate(t):
                    # Apply Separation
                    mixture, mix_len = batch.mix_sig
                    snt_id = batch.track_id
                    targets = [batch.voc_sig, batch.inst_sig]
                   

                    with torch.no_grad():
                        predictions, targets = self.compute_forward(
                            batch.mix_sig, targets, sb.Stage.TEST
                        )

                    # Compute SI-SNR
                    sisnr = self.compute_objectives(predictions, targets)

                    # Compute SI-SNR improvement
                    mixture_signal = torch.stack(
                        [mixture] * self.hparams.num_sources, dim=-1
                    )
                    mixture_signal = mixture_signal.to(targets.device)
                    sisnr_baseline = self.compute_objectives(
                        mixture_signal, targets
                    )
                    sisnr_i = sisnr - sisnr_baseline
                    
     
                    if not is_silent(targets[0].t().cpu().numpy()) and not is_silent(predictions[0].t().detach().cpu().numpy()) and not is_silent(mixture_signal[0].t().detach().cpu().numpy()):
                        
                    
                        sdr, _, _, _ = bss_eval_sources(
                            targets[0].t().cpu().numpy(),
                            predictions[0].t().detach().cpu().numpy(),
                            compute_permutation=False
                        )
    
                        sdr_baseline, _, _, _ = bss_eval_sources(
                            targets[0].t().cpu().numpy(),
                            mixture_signal[0].t().detach().cpu().numpy(),
                            compute_permutation=False
                        )
    
                        sdr_i = sdr.mean() - sdr_baseline.mean()
    
                        # Saving on a csv file
                        row = {
                            "snt_id": snt_id[0],
                            "sdr": sdr.mean(),
                            "sdr_i": sdr_i,
                            "si-snr": -sisnr.item(),
                            "si-snr_i": -sisnr_i.item(),
                        }
                        writer.writerow(row)
    
                        # Metric Accumulation
                        all_sdrs.append(sdr.mean())
                        all_sdrs_i.append(sdr_i.mean())
                        all_sisnrs.append(-sisnr.item())
                        all_sisnrs_i.append(-sisnr_i.item())
    
                else:
                    skip_cnt += 1
                    print(f"Warning: skipping silent target, this has happened {skip_cnt} times")
                row = {
                    "snt_id": "avg",
                    "sdr": np.array(all_sdrs).mean(),
                    "sdr_i": np.array(all_sdrs_i).mean(),
                    "si-snr": np.array(all_sisnrs).mean(),
                    "si-snr_i": np.array(all_sisnrs_i).mean(),
                }
                writer.writerow(row)
        
        logger.info("Mean SISNR is {}".format(np.array(all_sisnrs).mean()))
        logger.info("Mean SISNRi is {}".format(np.array(all_sisnrs_i).mean()))
        logger.info("Mean SDR is {}".format(np.array(all_sdrs).mean()))
        logger.info("Mean SDRi is {}".format(np.array(all_sdrs_i).mean()))

        if(self.hparams.result_file_path != ""):
            print("writing to file")
            with open(self.hparams.result_file_path, "a", newline="", encoding="utf-8") as metrics_csv:
                writer = csv.DictWriter(metrics_csv, fieldnames=["model_name", "n_epochs", "learning_rate", "chunk_size", "sample_rate", "sdr", "sdr_i", "si-snr", "si-snr_i"])
                row = {
                        "model_name": self.hparams.experiment_name,
                        "learning_rate": self.hparams.lr,
                        "n_epochs": self.hparams.N_epochs,
                        "chunk_size":self.hparams.chunk_size,
                        "sample_rate":self.hparams.sample_rate,
                        "sdr": np.array(all_sdrs).mean(),
                        "sdr_i": np.array(all_sdrs_i).mean(),
                        "si-snr": np.array(all_sisnrs).mean(),
                        "si-snr_i": np.array(all_sisnrs_i).mean(),
                    }
                writer.writerow(row)
            
        

    def save_audio(self, snt_id, mixture, targets, predictions):
        "saves the test audio (mixture, targets, and estimated sources) on disk"

        # Create output folder
        save_path = os.path.join(self.hparams.save_folder, "audio_results")
        if not os.path.exists(save_path):
            os.mkdir(save_path)

        for ns in range(self.hparams.num_sources):
            # Estimated source
            signal = predictions[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}hat.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

            # Original source
            signal = targets[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

        # Mixture
        signal = mixture[0][0, :]
        signal = signal / signal.abs().max()
        save_file = os.path.join(save_path, "item{}_mix.wav".format(snt_id))
        torchaudio.save(
            save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
        )





if __name__ == "__main__":
    # Load hyperparameters file with command-line overrides
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])
    with open(hparams_file, encoding="utf-8") as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Initialize ddp (useful only for multi-GPU DDP training)
    sb.utils.distributed.ddp_init_group(run_opts)

    # Logger info
    logger = get_logger(__name__)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Update precision to bf16 if the device is CPU and precision is fp16
    if run_opts.get("device") == "cpu" and hparams.get("precision") == "fp16":
        hparams["precision"] = "bf16"

   

    # Brain class initialization
    separator = Separation(
        modules=hparams["modules"],
        opt_class=hparams["optimizer"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )
 
    # Training
    # Usage with SpeechBrain
    train_data = MusDBDataset(hparams["db_path"], subset="train", split="train", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    valid_data = MusDBDataset(hparams["db_path"], subset="train", split="valid", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    test_data = MusDBDataset(hparams["db_path"], subset="test", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    

    
    # Create DataLoader
    train_loader = sb.dataio.dataloader.make_dataloader(
        train_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    valid_loader = sb.dataio.dataloader.make_dataloader(
        valid_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    test_loader = sb.dataio.dataloader.make_dataloader(
        test_data,
        batch_size=hparams["batch_size"],
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )
    
    separator.fit(
        separator.hparams.epoch_counter,
        train_loader,
        valid_loader,
        train_loader_kwargs=hparams["dataloader_opts"],
        valid_loader_kwargs=hparams["dataloader_opts"],
    )

    # # Eval
    separator.evaluate(test_loader, min_key="si-snr")
    separator.save_results(test_loader)
# Out:
# Overwriting convtasnet-train.py

# %%
# !python convtasnet-train.py convtasnet-hparams.yaml --data_folder=db_path --device "cpu"
# !torchrun --standalone --nproc_per_node=2 convtasnet-train.py convtasnet-hparams.yaml --data_folder={db_path} --result_file_path={result_file_path}
# Out:
# W0420 05:20:16.344000 247527 torch/distributed/run.py:793]
# W0420 05:20:16.344000 247527 torch/distributed/run.py:793] *****************************************
# W0420 05:20:16.344000 247527 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0420 05:20:16.344000 247527 torch/distributed/run.py:793] *****************************************
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: /kaggle/working/results/convtasnet/1234
# speechbrain.core - Info: precision arg from hparam file is used
# speechbrain.core - Info: noprogressbar arg from hparam file is used
# speechbrain.core - Gradscaler enabled: `True`
# speechbrain.core - Using training precision: `--precision=fp16`
# speechbrain.core - Using evaluation precision: `--eval_precision=fp32`
# speechbrain.core - Separation Model Statistics:
# * Total Number of Trainable Parameters: 6.6M
# * Total Number of Parameters: 6.6M
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-19+16-10-45+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100%|██████████████████████████| 81/81 [16:33<00:00, 12.27s/it, train_loss=3.88]
# 100%|███████████████████████████████████████████| 13/13 [02:48<00:00, 12.96s/it]
# speechbrain.utils.train_logger - epoch: 21, lr: 1.50e-04 - train si-snr: 3.88 - valid si-snr: 6.31
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+05-40-06+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-19+16-10-45+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100%|██████████████████████████| 81/81 [16:27<00:00, 12.19s/it, train_loss=3.84]
# 100%|███████████████████████████████████████████| 13/13 [02:47<00:00, 12.89s/it]
# speechbrain.utils.train_logger - epoch: 22, lr: 1.50e-04 - train si-snr: 3.84 - valid si-snr: 5.94
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+05-59-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+05-40-06+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100%|███████████████████████████| 81/81 [16:26<00:00, 12.18s/it, train_loss=3.4]
# 100%|███████████████████████████████████████████| 13/13 [02:48<00:00, 12.95s/it]
# speechbrain.utils.train_logger - epoch: 23, lr: 1.50e-04 - train si-snr: 3.40 - valid si-snr: 5.85
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+06-18-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-19+15-53-04+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+05-59-21+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100%|██████████████████████████| 81/81 [16:27<00:00, 12.20s/it, train_loss=3.17]
# 100%|███████████████████████████████████████████| 13/13 [02:49<00:00, 13.02s/it]
# speechbrain.utils.train_logger - epoch: 24, lr: 1.50e-04 - train si-snr: 3.17 - valid si-snr: 5.66
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+06-37-53+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+06-18-36+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100%|██████████████████████████| 81/81 [16:26<00:00, 12.18s/it, train_loss=2.85]
# 100%|███████████████████████████████████████████| 13/13 [02:48<00:00, 12.99s/it]
# speechbrain.utils.train_logger - epoch: 25, lr: 1.50e-04 - train si-snr: 2.85 - valid si-snr: 5.81
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+06-57-09+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100%|██████████████████████████| 81/81 [16:30<00:00, 12.23s/it, train_loss=3.44]
# 100%|███████████████████████████████████████████| 13/13 [02:50<00:00, 13.08s/it]
# speechbrain.utils.train_logger - epoch: 26, lr: 1.50e-04 - train si-snr: 3.44 - valid si-snr: 5.74
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+07-16-30+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+06-57-09+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100%|██████████████████████████| 81/81 [16:30<00:00, 12.23s/it, train_loss=2.99]
# 100%|███████████████████████████████████████████| 13/13 [02:49<00:00, 13.01s/it]
# speechbrain.utils.train_logger - epoch: 27, lr: 1.50e-04 - train si-snr: 2.99 - valid si-snr: 5.73
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+07-35-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+07-16-30+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100%|██████████████████████████| 81/81 [16:26<00:00, 12.18s/it, train_loss=3.27]
# 100%|███████████████████████████████████████████| 13/13 [02:48<00:00, 12.96s/it]
# speechbrain.utils.train_logger - epoch: 28, lr: 1.50e-04 - train si-snr: 3.27 - valid si-snr: 5.63
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+07-55-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+06-37-53+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+07-35-50+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100%|██████████████████████████| 81/81 [16:31<00:00, 12.24s/it, train_loss=2.75]
# 100%|███████████████████████████████████████████| 13/13 [02:48<00:00, 13.00s/it]
# speechbrain.utils.train_logger - epoch: 29, lr: 1.50e-04 - train si-snr: 2.75 - valid si-snr: 5.69
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-14-25+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100%|█████████████████████████████| 81/81 [16:27<00:00, 12.20s/it, train_loss=3]
# 100%|███████████████████████████████████████████| 13/13 [02:48<00:00, 12.95s/it]
# speechbrain.utils.train_logger - epoch: 30, lr: 1.50e-04 - train si-snr: 3.00 - valid si-snr: 5.46
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-14-25+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+07-55-05+00
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# 100%|███████████████████████████████████████████| 44/44 [09:12<00:00, 12.56s/it]
# speechbrain.utils.train_logger - Epoch loaded: 30 - test si-snr: 10.21
#   0%|                                                    | 0/44 [00:00<?, ?it/s]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:11<08:26, 11.78s/it]/kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:11<08:17, 11.56s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:23<08:06, 11.59s/it]/kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:22<08:00, 11.45s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:35<08:05, 11.84s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:52<09:20, 14.00s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [01:05<08:42, 13.41s/it]/kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [01:04<08:43, 13.41s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  14%|██████                                      | 6/44 [01:17<08:13, 12.99s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  16%|███████                                     | 7/44 [01:31<08:18, 13.48s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  18%|████████                                    | 8/44 [01:44<07:58, 13.30s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  23%|█████████▊                                 | 10/44 [02:07<06:56, 12.25s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  25%|██████████▊                                | 11/44 [02:18<06:27, 11.73s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  32%|█████████████▋                             | 14/44 [03:06<07:22, 14.76s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  34%|██████████████▋                            | 15/44 [03:15<06:17, 13.01s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  36%|███████████████▋                           | 16/44 [03:29<06:13, 13.33s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:41<05:52, 13.05s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:42<05:52, 13.07s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  41%|█████████████████▌                         | 18/44 [03:55<05:45, 13.27s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  43%|██████████████████▌                        | 19/44 [04:06<05:12, 12.49s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [04:19<05:01, 12.58s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [04:20<05:06, 12.77s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [04:33<05:00, 13.06s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [04:34<05:01, 13.13s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:50<05:11, 14.16s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:50<05:12, 14.19s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:59<04:28, 12.80s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [05:00<04:28, 12.78s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [05:05<03:37, 10.85s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [05:06<03:36, 10.85s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [05:18<03:35, 11.34s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [05:19<03:36, 11.40s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  59%|█████████████████████████▍                 | 26/44 [05:30<03:25, 11.42s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  61%|██████████████████████████▍                | 27/44 [05:45<03:30, 12.39s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  64%|███████████████████████████▎               | 28/44 [05:59<03:29, 13.07s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  66%|████████████████████████████▎              | 29/44 [06:12<03:13, 12.88s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [06:25<03:04, 13.15s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [06:25<03:01, 12.99s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  70%|██████████████████████████████▎            | 31/44 [06:35<02:39, 12.30s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  73%|███████████████████████████████▎           | 32/44 [06:53<02:43, 13.65s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [07:06<02:30, 13.68s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [07:06<02:29, 13.61s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [07:21<02:20, 14.08s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [07:21<02:20, 14.00s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [07:38<02:13, 14.88s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [07:38<02:13, 14.88s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [07:51<01:53, 14.24s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [07:51<01:54, 14.29s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  84%|████████████████████████████████████▏      | 37/44 [08:04<01:37, 13.95s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  86%|█████████████████████████████████████▏     | 38/44 [08:17<01:21, 13.58s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [08:33<01:11, 14.39s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [08:33<01:12, 14.44s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [08:46<00:56, 14.01s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [08:47<00:56, 14.08s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [08:56<00:38, 12.77s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [08:57<00:38, 12.94s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  95%|█████████████████████████████████████████  | 42/44 [09:09<00:25, 12.77s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  98%|██████████████████████████████████████████ | 43/44 [09:21<00:12, 12.29s/it]/kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [09:32<00:00, 13.01s/it]
# Warning: skipping silent target, this has happened 1 times
# writing to file
# /kaggle/working/convtasnet-train.py:252: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/convtasnet-train.py:258: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [09:33<00:00, 13.04s/it]
# Warning: skipping silent target, this has happened 1 times
# __main__ - Mean SISNR is -0.21834575264684616
# __main__ - Mean SISNRi is 1.4761062783579673
# __main__ - Mean SDR is -8.77199812524911
# __main__ - Mean SDRi is -9.516606062359672
# writing to file
# [rank0]:[W420 08:52:29.369278212 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %% [markdown]
# ## DPRNN (Dual-Path Recurrent Neural Network)
# We now progress to the next bigger model. This is a good next stage because it uses Recurrent Neural Networks.
#
# **Key Idea**:
# DPRNN is designed to model extremely long sequences efficiently by splitting input signals into smaller chunks and processing them through intra-chunk (local) and inter-chunk (global) RNNs. This dual-path approach addresses the limitations of traditional RNNs in handling long-term dependencies while maintaining low computational complexity.
#
# **Architecture**
# - Encoder: Converts input waveforms (or time-frequency representations) into latent features using 1D convolutions (time-domain).
# - Decoder: Reconstructs separated signals using transposed convolutions or overlap-add operations.
#
#
# ![image.png](attachment:7ae8c3f0-7263-4663-ae80-217e3a81c9a2.png)
#
# source: https://arxiv.org/pdf/1910.06379
#
#
# **Dual-Path Processing**:
# - Encoder and Decoder: Very Similar to ConvTasNet. Essentially a 1D encoder which converts our waveform input into latent representations for the model.
# - Intra-chunk RNN: Models local patterns within short segments. It essentially splits input into segments and then outputs locally enhanced features.
# - Inter-chunk RNN: Captures global dependencies across segments, enabling utterance-level modeling.
# - Mask Estimation: Learns soft masks in the latent space to separate sources, similar to ConvTasNet but with RNN-based temporal modeling.
#
# **Advantages**
# - Long-Sequence Modeling: Superior to 1D CNNs and vanilla RNNs for sequences with >100k time steps.
# - Versatility: Adaptable to time-domain (e.g., TasNet) and TF-domain tasks (e.g., speech enhancement).
#
# **Limitations**
# - Computational Overhead: RNNs may introduce higher latency compared to fully convolutional models like ConvTasNet.
# - Fixed Chunking: Performance depends on optimal chunk size selection.
#
#
#
# **Personal Interests**
# One interesting thing about this architecture is the fact that it is inspired by human learning. When humans read or listen to speach, we have a tendency to build context as we decipher short phenomes. i.e. each word or phenome is processed in its local as well as global context sequentially. This is what DPRNN aims to do.
#
# **References**
# - https://github.com/speechbrain/speechbrain/blob/develop/recipes/WSJ0Mix/separation/hparams/dprnn.yaml
# - https://github.com/speechbrain/speechbrain/blob/develop/recipes/WSJ0Mix/separation/train.py
# - https://arxiv.org/pdf/1910.06379
# - https://github.com/JusperLee/Dual-Path-RNN-Pytorch

# %%
# %%file dprnn-hparams.yaml
# # ################################
# # Model: DPRNN for Music vocal separation
# # https://arxiv.org/abs/2010.13154
# # Dataset : MusDB
# # ################################
# # Basic parameters
# # Seed needs to be set at top of yaml, before objects with parameters are made
#
#
# seed: 1234
# __set_seed: !apply:speechbrain.utils.seed_everything [!ref <seed>]
#
# # Data params
#
# data_folder: !PLACEHOLDER
#
#
# experiment_name: dprnn
# output_folder: !ref /kaggle/working/results/<experiment_name>/<seed>
# train_log: !ref <output_folder>/train_log.txt
# save_folder: !ref <output_folder>/save
# train_data: !ref <output_folder>/train.json
# valid_data: !ref <output_folder>/valid.json
# test_data: !ref <output_folder>/test.json
# skip_prep: False
# db_path: '/kaggle/input/musdb18-music-source-separation-dataset'
#
# result_file_path: !PLACEHOLDER
#
# # Experiment params
# precision: fp16 # bf16, fp16 or fp32
#
# noprogressbar: False
# save_audio: True # Save estimated sources on disk
# sample_rate: 16000
# n_audio_to_save: 10
# chunk_size: 10
#
# ####################### Training Parameters ####################################
# N_epochs: 30
# batch_size: 1
# lr: 0.00015
# clip_grad_norm: 5
# loss_upper_lim: 999999  # this is the upper limit for an acceptable loss
# num_sources: 2
#
#
#
# ####################### WaveDrop Params ########################################
#
# use_wavedrop: True
# # Frequency drop: randomly drops a number of frequency bands to zero.
# drop_freq_low: 0  # Min frequency band dropout probability
# drop_freq_high: 1  # Max frequency band dropout probability
# drop_freq_count_low: 1  # Min number of frequency bands to drop
# drop_freq_count_high: 3  # Max number of frequency bands to drop
# drop_freq_width: 0.05  # Width of frequency bands to drop
#
# drop_freq: !new:speechbrain.augment.time_domain.DropFreq
#     drop_freq_low: !ref <drop_freq_low>
#     drop_freq_high: !ref <drop_freq_high>
#     drop_freq_count_low: !ref <drop_freq_count_low>
#     drop_freq_count_high: !ref <drop_freq_count_high>
#     drop_freq_width: !ref <drop_freq_width>
#
# # Time drop: randomly drops a number of temporal chunks.
# drop_chunk_count_low: 1  # Min number of audio chunks to drop
# drop_chunk_count_high: 3  # Max number of audio chunks to drop
# drop_chunk_length_low: 1000  # Min length of audio chunks to drop
# drop_chunk_length_high: 2000  # Max length of audio chunks to drop
#
# drop_chunk: !new:speechbrain.augment.time_domain.DropChunk
#     drop_length_low: !ref <drop_chunk_length_low>
#     drop_length_high: !ref <drop_chunk_length_high>
#     drop_count_low: !ref <drop_chunk_count_low>
#     drop_count_high: !ref <drop_chunk_count_high>
#
# # loss thresholding -- this thresholds the training loss
# threshold_byloss: True
# threshold: -30
#
# # Encoder parameters
# N_encoder_out: 256
# out_channels: 256
# kernel_size: 16
# kernel_stride: 8
#
# # Dataloader options
# dataloader_opts:
#     batch_size: !ref <batch_size>
#     num_workers: 3
#
#
# # Specifying the network
# Encoder: !new:speechbrain.lobes.models.dual_path.Encoder
#     kernel_size: !ref <kernel_size>
#     out_channels: !ref <N_encoder_out>
#
# intra: !new:speechbrain.lobes.models.dual_path.SBRNNBlock
#     num_layers: 1
#     input_size: !ref <out_channels>
#     hidden_channels: !ref <out_channels>
#     dropout: 0
#     bidirectional: True
#
# inter: !new:speechbrain.lobes.models.dual_path.SBRNNBlock
#     num_layers: 1
#     input_size: !ref <out_channels>
#     hidden_channels: !ref <out_channels>
#     dropout: 0
#     bidirectional: True
#
# MaskNet: !new:speechbrain.lobes.models.dual_path.Dual_Path_Model
#     num_spks: !ref <num_sources>
#     in_channels: !ref <N_encoder_out>
#     out_channels: !ref <out_channels>
#     num_layers: 6
#     K: 250
#     intra_model: !ref <intra>
#     inter_model: !ref <inter>
#     norm: ln
#     linear_layer_after_inter_intra: True
#     skip_around_intra: True
#
# Decoder: !new:speechbrain.lobes.models.dual_path.Decoder
#     in_channels: !ref <N_encoder_out>
#     out_channels: 1
#     kernel_size: !ref <kernel_size>
#     stride: !ref <kernel_stride>
#     bias: False
#
# optimizer: !name:torch.optim.Adam
#     lr: !ref <lr>
#     weight_decay: 0
#
# loss: !name:speechbrain.nnet.losses.get_si_snr_with_pitwrapper
#
# lr_scheduler: !new:speechbrain.nnet.schedulers.ReduceLROnPlateau
#     factor: 0.5
#     patience: 2
#     dont_halve_until_epoch: 85
#
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <N_epochs>
#
# modules:
#     encoder: !ref <Encoder>
#     decoder: !ref <Decoder>
#     masknet: !ref <MaskNet>
#
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         encoder: !ref <Encoder>
#         decoder: !ref <Decoder>
#         masknet: !ref <MaskNet>
#         counter: !ref <epoch_counter>
#         lr_scheduler: !ref <lr_scheduler>
#
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
# Out:
# Overwriting dprnn-hparams.yaml

# %%
# %%file dprnn-train.py
#!/usr/bin/env/python3
"""
Recipe for vocal separation using convtasnet
"""

import csv
import os
import sys

import numpy as np
import torch
import torch.nn.functional as F
import torchaudio
from hyperpyyaml import load_hyperpyyaml
from tqdm import tqdm
import pdb

import musdb
import torchaudio
import numpy as np
from torch.utils.data import Dataset
import speechbrain as sb
import psutil
from dataset import MusDBDataset


import speechbrain as sb
import speechbrain.nnet.schedulers as schedulers
from speechbrain.core import AMPConfig
from speechbrain.utils.distributed import run_on_main
from speechbrain.utils.logger import get_logger
import time
from torch.utils.data import DataLoader

import musdb


# Define training procedure
class Separation(sb.Brain):
    def compute_forward(self, mix, targets, stage, noise=None):
        """Forward computations from the mixture to the separated signals."""

        # Unpack lists and put tensors in the right device
        mix, mix_lens = mix       
        mix, mix_lens = mix.to(self.device), mix_lens.to(self.device)      

        # Convert targets to tensor
        targets = torch.cat(
            [targets[i][0].unsqueeze(-1) for i in range(self.hparams.num_sources)],
            dim=-1,
        ).to(self.device)

        if stage == sb.Stage.TRAIN:
            with torch.no_grad():
                if self.hparams.use_wavedrop:
                    mix = self.hparams.drop_chunk(mix, mix_lens)
                    mix = self.hparams.drop_freq(mix)
        
        # Separation
        mix_w = self.hparams.Encoder(mix)
        est_mask = self.hparams.MaskNet(mix_w)
        mix_w = torch.stack([mix_w] * self.hparams.num_sources)
        sep_h = mix_w * est_mask
        
        # Decoding
        est_source = torch.cat(
            [
                self.hparams.Decoder(sep_h[i]).unsqueeze(-1)
                for i in range(self.hparams.num_sources)
            ],
            dim=-1,
        )

        # pad estimates as per requirement 
        T_origin = mix.size(1)
        T_est = est_source.size(1)
        if T_origin > T_est:
            est_source = F.pad(est_source, (0, 0, 0, T_origin - T_est))
        else:
            est_source = est_source[:, :T_origin, :]

        return est_source, targets

    def compute_objectives(self, predictions, targets):
        """Computes the sinr loss"""
        return self.hparams.loss(targets, predictions)

    def fit_batch(self, batch):
        """Trains one batch"""
        # print("INSIDE FIT BATCH")
        
        amp = AMPConfig.from_name(self.precision)
        should_step = (self.step % self.grad_accumulation_factor) == 0
        # Unpacking batch list
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig] #mix_sig, voc_sig, inst_sig
       
        
        predictions, targets = self.compute_forward(
            mixture, targets, sb.Stage.TRAIN
        )
        loss = self.compute_objectives(predictions, targets)

        if self.hparams.threshold_byloss:
            th = self.hparams.threshold
            loss = loss[loss > th]
            if loss.nelement() > 0:
                loss = loss.mean()
        else:
            loss = loss.mean()

        if (
            loss.nelement() > 0 and loss < self.hparams.loss_upper_lim
        ):  # the fix for computational problems
            loss.backward()
            if self.hparams.clip_grad_norm >= 0:
                torch.nn.utils.clip_grad_norm_(
                    self.modules.parameters(),
                    self.hparams.clip_grad_norm,
                )
            self.optimizer.step()
        else:
            self.nonfinite_count += 1
            logger.info(
                "infinite loss or empty loss! it happened {} times so far - skipping this batch".format(
                    self.nonfinite_count
                )
            )
            loss.data = torch.tensor(0.0).to(self.device)
        self.optimizer.zero_grad()

        return loss.detach().cpu()

    def evaluate_batch(self, batch, stage):
        """Computations needed for validation/test batches"""
        snt_id = batch.track_id
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig]

        with torch.no_grad():
            predictions, targets = self.compute_forward(mixture, targets, stage)
            loss = self.compute_objectives(predictions, targets)

        # Manage audio file saving
        if stage == sb.Stage.TEST and self.hparams.save_audio:
            if hasattr(self.hparams, "n_audio_to_save"):
                if self.hparams.n_audio_to_save > 0:
                    self.save_audio(snt_id[0], mixture, targets, predictions)
                    self.hparams.n_audio_to_save += -1
            else:
                self.save_audio(snt_id[0], mixture, targets, predictions)

        return loss.mean().detach()

    def on_stage_end(self, stage, stage_loss, epoch):
        """Gets called at the end of a epoch."""
        # Compute/store important stats
        stage_stats = {"si-snr": stage_loss}
        if stage == sb.Stage.TRAIN:
            self.train_stats = stage_stats

        # Perform end-of-iteration things, like annealing, logging, etc.
        if stage == sb.Stage.VALID:
            # Learning rate annealing
            if isinstance(
                self.hparams.lr_scheduler, schedulers.ReduceLROnPlateau
            ):
                current_lr, next_lr = self.hparams.lr_scheduler(
                    [self.optimizer], epoch, stage_loss
                )
                schedulers.update_learning_rate(self.optimizer, next_lr)
            else:
                # if we do not use the reducelronplateau, we do not change the lr
                current_lr = self.hparams.optimizer.optim.param_groups[0]["lr"]

            self.hparams.train_logger.log_stats(
                stats_meta={"epoch": epoch, "lr": current_lr},
                train_stats=self.train_stats,
                valid_stats=stage_stats,
            )
            self.checkpointer.save_and_keep_only(
                meta={"si-snr": stage_stats["si-snr"]}, min_keys=["si-snr"]
            )
        elif stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                stats_meta={"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stage_stats,
            )


    def cut_signals(self, mixture, targets):
        """This function selects a random segment of a given length within the mixture.
        The corresponding targets are selected accordingly"""
        randstart = torch.randint(
            0,
            1 + max(0, mixture.shape[1] - self.hparams.training_signal_len),
            (1,),
        ).item()
        targets = targets[
            :, randstart : randstart + self.hparams.training_signal_len, :
        ]
        mixture = mixture[
            :, randstart : randstart + self.hparams.training_signal_len
        ]
        return mixture, targets

    def reset_layer_recursively(self, layer):
        """Reinitializes the parameters of the neural networks"""
        if hasattr(layer, "reset_parameters"):
            layer.reset_parameters()
        for child_layer in layer.modules():
            if layer != child_layer:
                self.reset_layer_recursively(child_layer)

    def save_results(self, test_loader):
        """This script computes the SDR and SI-SNR metrics and saves
        them into a csv file"""

        # This package is required for SDR computation
        from mir_eval.separation import bss_eval_sources

        # Create folders where to store audio
        save_file = os.path.join(self.hparams.output_folder, "test_results.csv")

        # Variable init
        all_sdrs = []
        all_sdrs_i = []
        all_sisnrs = []
        all_sisnrs_i = []
        csv_columns = ["snt_id", "sdr", "sdr_i", "si-snr", "si-snr_i"]


        def is_silent(source, threshold=1e-6):
            return np.max(np.abs(source[0])) < threshold or np.max(np.abs(source[1])) < threshold

        with open(save_file, "w", newline="", encoding="utf-8") as results_csv:
            writer = csv.DictWriter(results_csv, fieldnames=csv_columns)
            writer.writeheader()
            skip_cnt = 0

            # Loop over all test sentence
            with tqdm(test_loader, dynamic_ncols=True) as t:
                for i, batch in enumerate(t):
                    # Apply Separation
                    mixture, mix_len = batch.mix_sig
                    snt_id = batch.track_id
                    targets = [batch.voc_sig, batch.inst_sig]
                   

                    with torch.no_grad():
                        predictions, targets = self.compute_forward(
                            batch.mix_sig, targets, sb.Stage.TEST
                        )

                    # Compute SI-SNR
                    sisnr = self.compute_objectives(predictions, targets)

                    # Compute SI-SNR improvement
                    mixture_signal = torch.stack(
                        [mixture] * self.hparams.num_sources, dim=-1
                    )
                    mixture_signal = mixture_signal.to(targets.device)
                    sisnr_baseline = self.compute_objectives(
                        mixture_signal, targets
                    )
                    sisnr_i = sisnr - sisnr_baseline
                    
     
                    if not is_silent(targets[0].t().cpu().numpy()) and not is_silent(predictions[0].t().detach().cpu().numpy()) and not is_silent(mixture_signal[0].t().detach().cpu().numpy()):
                        
                    
                        sdr, _, _, _ = bss_eval_sources(
                            targets[0].t().cpu().numpy(),
                            predictions[0].t().detach().cpu().numpy(),
                            compute_permutation=False
                        )
    
                        sdr_baseline, _, _, _ = bss_eval_sources(
                            targets[0].t().cpu().numpy(),
                            mixture_signal[0].t().detach().cpu().numpy(),
                            compute_permutation=False
                        )
    
                        sdr_i = sdr.mean() - sdr_baseline.mean()
    
                        # Saving on a csv file
                        row = {
                            "snt_id": snt_id[0],
                            "sdr": sdr.mean(),
                            "sdr_i": sdr_i,
                            "si-snr": -sisnr.item(),
                            "si-snr_i": -sisnr_i.item(),
                        }
                        writer.writerow(row)
    
                        # Metric Accumulation
                        all_sdrs.append(sdr.mean())
                        all_sdrs_i.append(sdr_i.mean())
                        all_sisnrs.append(-sisnr.item())
                        all_sisnrs_i.append(-sisnr_i.item())
    
                    
                else:
                    skip_cnt += 1
                    print(f"Warning: skipping silent target, this has happened {skip_cnt} times")
                
                row = {
                    "snt_id": "avg",
                    "sdr": np.array(all_sdrs).mean(),
                    "sdr_i": np.array(all_sdrs_i).mean(),
                    "si-snr": np.array(all_sisnrs).mean(),
                    "si-snr_i": np.array(all_sisnrs_i).mean(),
                }
                writer.writerow(row)

        logger.info("Mean SISNR is {}".format(np.array(all_sisnrs).mean()))
        logger.info("Mean SISNRi is {}".format(np.array(all_sisnrs_i).mean()))
        logger.info("Mean SDR is {}".format(np.array(all_sdrs).mean()))
        logger.info("Mean SDRi is {}".format(np.array(all_sdrs_i).mean()))
        if(self.hparams.result_file_path is not None and self.hparams.result_file_path != ""):
            with open(self.hparams.result_file_path, "a", newline="", encoding="utf-8") as metrics_csv:
                writer = csv.DictWriter(metrics_csv, fieldnames=["model_name", "n_epochs", "learning_rate", "chunk_size", "sample_rate", "sdr", "sdr_i", "si-snr", "si-snr_i"])
                row = {
                        "model_name": self.hparams.experiment_name,
                        "learning_rate": self.hparams.lr,
                        "n_epochs": self.hparams.N_epochs,
                        "chunk_size":self.hparams.chunk_size,
                        "sample_rate":self.hparams.sample_rate,
                        "sdr": np.array(all_sdrs).mean(),
                        "sdr_i": np.array(all_sdrs_i).mean(),
                        "si-snr": np.array(all_sisnrs).mean(),
                        "si-snr_i": np.array(all_sisnrs_i).mean(),
                    }
                writer.writerow(row)

    def save_audio(self, snt_id, mixture, targets, predictions):
        "saves the test audio (mixture, targets, and estimated sources) on disk"

        # Create output folder
        save_path = os.path.join(self.hparams.save_folder, "audio_results")
        if not os.path.exists(save_path):
            os.mkdir(save_path)

        for ns in range(self.hparams.num_sources):
            # Estimated source
            signal = predictions[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}hat.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

            # Original source
            signal = targets[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

        # Mixture
        signal = mixture[0][0, :]
        signal = signal / signal.abs().max()
        save_file = os.path.join(save_path, "item{}_mix.wav".format(snt_id))
        torchaudio.save(
            save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
        )





if __name__ == "__main__":
    # Load hyperparameters file with command-line overrides
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])
    with open(hparams_file, encoding="utf-8") as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Initialize ddp (useful only for multi-GPU DDP training)
    sb.utils.distributed.ddp_init_group(run_opts)

    # Logger info
    logger = get_logger(__name__)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Update precision to bf16 if the device is CPU and precision is fp16
    if run_opts.get("device") == "cpu" and hparams.get("precision") == "fp16":
        hparams["precision"] = "bf16"

   

    # Brain class initialization
    separator = Separation(
        modules=hparams["modules"],
        opt_class=hparams["optimizer"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )
 
    # Training
        
    # Usage with SpeechBrain
    train_data = MusDBDataset(hparams["db_path"], subset="train", split="train", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    valid_data = MusDBDataset(hparams["db_path"], subset="train", split="valid", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    test_data = MusDBDataset(hparams["db_path"], subset="test", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    

    # Create DataLoader
    train_loader = sb.dataio.dataloader.make_dataloader(
        train_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    valid_loader = sb.dataio.dataloader.make_dataloader(
        valid_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    test_loader = sb.dataio.dataloader.make_dataloader(
        test_data,
        batch_size=hparams["batch_size"],
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )
    
    separator.fit(
        separator.hparams.epoch_counter,
        train_loader,
        valid_loader,
        train_loader_kwargs=hparams["dataloader_opts"],
        valid_loader_kwargs=hparams["dataloader_opts"],
    )

    # # Eval
    separator.evaluate(test_loader, min_key="si-snr")
    separator.save_results(test_loader)
# Out:
# Overwriting dprnn-train.py

# %%
# !python dprnn-train.py dprnn-hparams.yaml --data_folder=db_path
# !torchrun --standalone --nproc_per_node=2 dprnn-train.py dprnn-hparams.yaml --data_folder=db_path --result_file_path={result_file_path}
# Out:
# W0420 11:37:53.339000 153 torch/distributed/run.py:793]
# W0420 11:37:53.339000 153 torch/distributed/run.py:793] *****************************************
# W0420 11:37:53.339000 153 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0420 11:37:53.339000 153 torch/distributed/run.py:793] *****************************************
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: /kaggle/working/results/dprnn/1234
# speechbrain.core - Info: precision arg from hparam file is used
# speechbrain.core - Info: noprogressbar arg from hparam file is used
# speechbrain.core - Gradscaler enabled: `True`
# speechbrain.core - Using training precision: `--precision=fp16`
# speechbrain.core - Using evaluation precision: `--eval_precision=fp32`
# speechbrain.core - Separation Model Statistics:
# * Total Number of Trainable Parameters: 14.6M
# * Total Number of Parameters: 14.6M
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+09-13-22+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100%|███████████████████████████| 81/81 [20:07<00:00, 14.90s/it, train_loss=4.2]
# 100%|███████████████████████████████████████████| 13/13 [03:27<00:00, 15.97s/it]
# speechbrain.utils.train_logger - epoch: 22, lr: 1.50e-04 - train si-snr: 4.20 - valid si-snr: 5.30
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-19+19-36-59+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+09-13-22+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100%|██████████████████████████| 81/81 [15:58<00:00, 11.83s/it, train_loss=4.22]
# 100%|███████████████████████████████████████████| 13/13 [02:37<00:00, 12.10s/it]
# speechbrain.utils.train_logger - epoch: 23, lr: 1.50e-04 - train si-snr: 4.22 - valid si-snr: 5.49
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-20-33+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100%|██████████████████████████| 81/81 [15:46<00:00, 11.69s/it, train_loss=4.09]
# 100%|███████████████████████████████████████████| 13/13 [02:36<00:00, 12.07s/it]
# speechbrain.utils.train_logger - epoch: 24, lr: 1.50e-04 - train si-snr: 4.09 - valid si-snr: 5.50
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-38-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-20-33+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100%|██████████████████████████| 81/81 [15:45<00:00, 11.67s/it, train_loss=4.29]
# 100%|███████████████████████████████████████████| 13/13 [02:36<00:00, 12.07s/it]
# speechbrain.utils.train_logger - epoch: 25, lr: 1.50e-04 - train si-snr: 4.29 - valid si-snr: 6.07
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-57-19+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-38-56+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100%|██████████████████████████| 81/81 [15:42<00:00, 11.64s/it, train_loss=4.13]
# 100%|███████████████████████████████████████████| 13/13 [02:37<00:00, 12.08s/it]
# speechbrain.utils.train_logger - epoch: 26, lr: 1.50e-04 - train si-snr: 4.13 - valid si-snr: 5.91
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+13-15-39+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-57-19+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100%|██████████████████████████| 81/81 [15:53<00:00, 11.78s/it, train_loss=3.68]
# 100%|███████████████████████████████████████████| 13/13 [02:38<00:00, 12.21s/it]
# speechbrain.utils.train_logger - epoch: 27, lr: 1.50e-04 - train si-snr: 3.68 - valid si-snr: 5.96
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+13-34-12+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+13-15-39+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100%|██████████████████████████| 81/81 [15:48<00:00, 11.72s/it, train_loss=3.55]
# 100%|███████████████████████████████████████████| 13/13 [02:36<00:00, 12.01s/it]
# speechbrain.utils.train_logger - epoch: 28, lr: 1.50e-04 - train si-snr: 3.55 - valid si-snr: 6.04
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+13-52-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+13-34-12+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100%|██████████████████████████| 81/81 [15:42<00:00, 11.64s/it, train_loss=3.49]
# 100%|███████████████████████████████████████████| 13/13 [02:35<00:00, 11.99s/it]
# speechbrain.utils.train_logger - epoch: 29, lr: 1.50e-04 - train si-snr: 3.49 - valid si-snr: 5.46
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-10-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+13-52-38+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100%|██████████████████████████| 81/81 [15:48<00:00, 11.71s/it, train_loss=3.71]
# 100%|███████████████████████████████████████████| 13/13 [02:36<00:00, 12.01s/it]
# speechbrain.utils.train_logger - epoch: 30, lr: 1.50e-04 - train si-snr: 3.71 - valid si-snr: 5.45
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-10-56+00
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# 100%|███████████████████████████████████████████| 44/44 [10:55<00:00, 14.89s/it]
# speechbrain.utils.train_logger - Epoch loaded: 22 - test si-snr: 9.06
#   0%|                                                    | 0/44 [00:00<?, ?it/s]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:11<08:00, 11.18s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:21<07:39, 10.94s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:32<07:23, 10.82s/it]/kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:32<07:30, 10.98s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:48<08:28, 12.72s/it]/kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:48<08:33, 12.83s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [00:58<07:46, 11.95s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [00:59<07:55, 12.20s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  14%|██████                                      | 6/44 [01:10<07:25, 11.73s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  16%|███████                                     | 7/44 [01:23<07:32, 12.22s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  18%|████████                                    | 8/44 [01:35<07:19, 12.20s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  23%|█████████▊                                 | 10/44 [01:57<06:22, 11.24s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  25%|██████████▊                                | 11/44 [02:06<05:58, 10.85s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  32%|█████████████▋                             | 14/44 [02:52<06:53, 13.78s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  34%|██████████████▋                            | 15/44 [02:59<05:51, 12.11s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  36%|███████████████▋                           | 16/44 [03:14<05:47, 12.40s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:24<05:24, 12.01s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:25<05:28, 12.16s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  41%|█████████████████▌                         | 18/44 [03:36<05:15, 12.15s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  43%|██████████████████▌                        | 19/44 [03:48<04:50, 11.62s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [03:58<04:41, 11.73s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [04:00<04:43, 11.81s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [04:11<04:39, 12.14s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [04:13<04:38, 12.12s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:27<04:49, 13.18s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:28<04:49, 13.14s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:36<04:10, 11.95s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:38<04:10, 11.94s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [04:42<03:23, 10.19s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [04:44<03:23, 10.16s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [04:54<03:21, 10.61s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [04:55<03:21, 10.58s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  59%|█████████████████████████▍                 | 26/44 [05:05<03:12, 10.69s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  61%|██████████████████████████▍                | 27/44 [05:20<03:16, 11.56s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  64%|███████████████████████████▎               | 28/44 [05:31<03:13, 12.06s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  66%|████████████████████████████▎              | 29/44 [05:45<02:59, 11.94s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [05:55<02:46, 11.92s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [05:57<02:48, 12.04s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  70%|██████████████████████████████▎            | 31/44 [06:04<02:26, 11.25s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  73%|███████████████████████████████▎           | 32/44 [06:22<02:30, 12.56s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [06:32<02:17, 12.49s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [06:35<02:17, 12.46s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [06:47<02:10, 13.09s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [06:48<02:08, 12.81s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [07:02<02:03, 13.70s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [07:03<02:01, 13.47s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [07:14<01:45, 13.21s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [07:15<01:44, 13.07s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  84%|████████████████████████████████████▏      | 37/44 [07:26<01:30, 12.91s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  86%|█████████████████████████████████████▏     | 38/44 [07:40<01:15, 12.57s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [07:53<01:06, 13.24s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [07:54<01:05, 13.16s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [08:05<00:52, 13.04s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [08:07<00:51, 12.97s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [08:15<00:36, 12.00s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [08:16<00:35, 11.99s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  95%|█████████████████████████████████████████  | 42/44 [08:27<00:23, 11.85s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  98%|██████████████████████████████████████████ | 43/44 [08:38<00:11, 11.43s/it]/kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [08:48<00:00, 12.02s/it]
# Warning: skipping silent target, this has happened 1 times
# /kaggle/working/dprnn-train.py:272: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/dprnn-train.py:278: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [08:50<00:00, 12.06s/it]
# Warning: skipping silent target, this has happened 1 times
# __main__ - Mean SISNR is 1.3568804725523917
# __main__ - Mean SISNRi is 3.0513324679866916
# __main__ - Mean SDR is 4.229524443516624
# __main__ - Mean SDRi is 3.4849165064060643
# [rank0]:[W420 14:49:08.893260546 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %% [markdown]
# ## Sepformer (Transformer-based Source Separation)
#
# **Key Idea**
# SepFormer introduces a transformer-based architecture for speech separation, combining the advantages of self-attention mechanisms with dual-path processing. It achieves state-of-the-art performance by modeling both local and global dependencies through stacked transformer layers, outperforming RNN-based approaches like DPRNN in terms of scale and accuracy.
#
# **Architecture**
# Encoder-Decoder:
# - Encoder: 1D convolutions to project waveforms into a latent space (similar to DPRNN).
# - Decoder: Transposed convolutions to reconstruct separated sources.
#
# Dual-Path Transformer:
# - Intra-Chunk Transformer: Processes local segments (e.g., 25-ms windows) with self-attention.
# - Inter-Chunk Transformer: Captures global dependencies across segments via cross-attention.
# - Mask Estimation: Learns multiplicative masks in the latent space (like DPRNN but with transformer-based attention).
#
# ![image.png](attachment:cf2506a0-0cf2-437f-86fe-c7f0a320aeff.png)
#
# Source: https://arxiv.org/pdf/2010.13154
#
# **Advantages**
# - Higher SDR: Achieves >20 dB SI-SNRi on WSJ0-2mix (vs. ~18 dB for DPRNN).
# - Parallelizability: No sequential RNN constraints; faster training on GPUs.
# - Scalability: Handles variable-length inputs better than fixed-chunk RNN approaches.
#
# **Limitations**
# - Memory Usage: Quadratic attention complexity limits maximum sequence length.
# - Compute Cost: Requires more FLOPs than DPRNN for real-time applications.
#
# **Personal Interest**
# SepFormer demonstrates that transformers can surpass RNNs in speech separation when combined with dual-path processing. Its hybrid local/global attention design bridges the gap between computational efficiency and separation quality. In order to run the transformer efficiently, we train on two heads only
#
#
# **References**
# - https://arxiv.org/pdf/2010.13154
# - https://github.com/speechbrain/speechbrain/blob/develop/recipes/WSJ0Mix/separation/hparams/sepformer.yaml

# %%
# %%file sepformer-hparams.yaml
# # ################################
# # Model: Sepformer for Music vocal separation
# # https://arxiv.org/abs/2010.13154
# # Dataset : MusDB
# # ################################
# # Basic parameters
# # Seed needs to be set at top of yaml, before objects with parameters are made
#
#
# seed: 1234
# __set_seed: !apply:speechbrain.utils.seed_everything [!ref <seed>]
#
# # Data params
#
# data_folder: !PLACEHOLDER
#
#
# experiment_name: sepformer
# output_folder: !ref /kaggle/working/results/<experiment_name>/<seed>
# train_log: !ref <output_folder>/train_log.txt
# save_folder: !ref <output_folder>/save
# train_data: !ref <output_folder>/train.json
# valid_data: !ref <output_folder>/valid.json
# test_data: !ref <output_folder>/test.json
# skip_prep: False
# db_path: '/kaggle/input/musdb18-music-source-separation-dataset'
#
# result_file_path: !PLACEHOLDER
#
#
# # Experiment params
# precision: fp16 # bf16, fp16 or fp32
#
# noprogressbar: False
# save_audio: True # Save estimated sources on disk
# sample_rate: 16000
# n_audio_to_save: 5
# chunk_size: 10
#
# ####################### Training Parameters ####################################
# N_epochs: 30
# batch_size: 1
# lr: 0.00015
# clip_grad_norm: 5
# loss_upper_lim: 999999  # this is the upper limit for an acceptable loss
# num_sources: 2
#
#
#
# # loss thresholding -- this thresholds the training loss
# threshold_byloss: True
# threshold: -30
#
# # Encoder parameters
# N_encoder_out: 256
# out_channels: 256
# kernel_size: 16
# kernel_stride: 8
#
# # Dataloader options
# dataloader_opts:
#     batch_size: !ref <batch_size>
#     num_workers: 3
#
#
#
# ####################### WaveDrop Params ########################################
#
# use_wavedrop: True
# # Frequency drop: randomly drops a number of frequency bands to zero.
# drop_freq_low: 0  # Min frequency band dropout probability
# drop_freq_high: 1  # Max frequency band dropout probability
# drop_freq_count_low: 1  # Min number of frequency bands to drop
# drop_freq_count_high: 3  # Max number of frequency bands to drop
# drop_freq_width: 0.05  # Width of frequency bands to drop
#
# drop_freq: !new:speechbrain.augment.time_domain.DropFreq
#     drop_freq_low: !ref <drop_freq_low>
#     drop_freq_high: !ref <drop_freq_high>
#     drop_freq_count_low: !ref <drop_freq_count_low>
#     drop_freq_count_high: !ref <drop_freq_count_high>
#     drop_freq_width: !ref <drop_freq_width>
#
# # Time drop: randomly drops a number of temporal chunks.
# drop_chunk_count_low: 1  # Min number of audio chunks to drop
# drop_chunk_count_high: 3  # Max number of audio chunks to drop
# drop_chunk_length_low: 1000  # Min length of audio chunks to drop
# drop_chunk_length_high: 2000  # Max length of audio chunks to drop
#
# drop_chunk: !new:speechbrain.augment.time_domain.DropChunk
#     drop_length_low: !ref <drop_chunk_length_low>
#     drop_length_high: !ref <drop_chunk_length_high>
#     drop_count_low: !ref <drop_chunk_count_low>
#     drop_count_high: !ref <drop_chunk_count_high>
#
#
# # Specifying the network
# Encoder: !new:speechbrain.lobes.models.dual_path.Encoder
#     kernel_size: !ref <kernel_size>
#     out_channels: !ref <N_encoder_out>
#
#
# SBtfintra: !new:speechbrain.lobes.models.dual_path.SBTransformerBlock
#     num_layers: 2
#     d_model: !ref <out_channels>
#     nhead: 4
#     d_ffn: 1024
#     dropout: 0
#     use_positional_encoding: True
#     norm_before: True
#
# SBtfinter: !new:speechbrain.lobes.models.dual_path.SBTransformerBlock
#     num_layers: 2
#     d_model: !ref <out_channels>
#     nhead: 4
#     d_ffn: 1024
#     dropout: 0
#     use_positional_encoding: True
#     norm_before: True
#
# MaskNet: !new:speechbrain.lobes.models.dual_path.Dual_Path_Model
#     num_spks: !ref <num_sources>
#     in_channels: !ref <N_encoder_out>
#     out_channels: !ref <out_channels>
#     num_layers: 2
#     K: 250
#     intra_model: !ref <SBtfintra>
#     inter_model: !ref <SBtfinter>
#     norm: ln
#     linear_layer_after_inter_intra: False
#     skip_around_intra: True
#
# Decoder: !new:speechbrain.lobes.models.dual_path.Decoder
#     in_channels: !ref <N_encoder_out>
#     out_channels: 1
#     kernel_size: !ref <kernel_size>
#     stride: !ref <kernel_stride>
#     bias: False
#
# optimizer: !name:torch.optim.Adam
#     lr: !ref <lr>
#     weight_decay: 0
#
# loss: !name:speechbrain.nnet.losses.get_si_snr_with_pitwrapper
#
# lr_scheduler: !new:speechbrain.nnet.schedulers.ReduceLROnPlateau
#     factor: 0.5
#     patience: 2
#     dont_halve_until_epoch: 85
#
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <N_epochs>
#
# modules:
#     encoder: !ref <Encoder>
#     decoder: !ref <Decoder>
#     masknet: !ref <MaskNet>
#
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         encoder: !ref <Encoder>
#         decoder: !ref <Decoder>
#         masknet: !ref <MaskNet>
#         counter: !ref <epoch_counter>
#         lr_scheduler: !ref <lr_scheduler>
#
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
# Out:
# Overwriting sepformer-hparams.yaml

# %%
# %%file sepformer-train.py
#!/usr/bin/env/python3
"""
Recipe for vocal separation using convtasnet
"""

import csv
import os
import sys

import numpy as np
import torch
import torch.nn.functional as F
import torchaudio
from hyperpyyaml import load_hyperpyyaml
from tqdm import tqdm
import pdb

import musdb
import torchaudio
import numpy as np
from torch.utils.data import Dataset
import speechbrain as sb
import psutil
from dataset import MusDBDataset


import speechbrain as sb
import speechbrain.nnet.schedulers as schedulers
from speechbrain.core import AMPConfig
from speechbrain.utils.distributed import run_on_main
from speechbrain.utils.logger import get_logger
import time
from torch.utils.data import DataLoader

import musdb


# Define training procedure
class Separation(sb.Brain):
    def compute_forward(self, mix, targets, stage, noise=None):
        """Forward computations from the mixture to the separated signals."""

        # Unpack lists and put tensors in the right device
        mix, mix_lens = mix       
        mix, mix_lens = mix.to(self.device), mix_lens.to(self.device)      

        # Convert targets to tensor
        targets = torch.cat(
            [targets[i][0].unsqueeze(-1) for i in range(self.hparams.num_sources)],
            dim=-1,
        ).to(self.device)

        if stage == sb.Stage.TRAIN:
            with torch.no_grad():
    
                if self.hparams.use_wavedrop:
                    mix = self.hparams.drop_chunk(mix, mix_lens)
                    mix = self.hparams.drop_freq(mix)
        
        # Separation
        mix_w = self.hparams.Encoder(mix)
        est_mask = self.hparams.MaskNet(mix_w)
        mix_w = torch.stack([mix_w] * self.hparams.num_sources)
        sep_h = mix_w * est_mask
        
        # Decoding
        est_source = torch.cat(
            [
                self.hparams.Decoder(sep_h[i]).unsqueeze(-1)
                for i in range(self.hparams.num_sources)
            ],
            dim=-1,
        )

        # pad estimates as per requirement 
        T_origin = mix.size(1)
        T_est = est_source.size(1)
        if T_origin > T_est:
            est_source = F.pad(est_source, (0, 0, 0, T_origin - T_est))
        else:
            est_source = est_source[:, :T_origin, :]

        return est_source, targets

    def compute_objectives(self, predictions, targets):
        """Computes the sinr loss"""
        return self.hparams.loss(targets, predictions)

    def fit_batch(self, batch):
        """Trains one batch"""
        
        
        amp = AMPConfig.from_name(self.precision)
        should_step = (self.step % self.grad_accumulation_factor) == 0
        # Unpacking batch list
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig] #mix_sig, voc_sig, inst_sig
       
        
        predictions, targets = self.compute_forward(
            mixture, targets, sb.Stage.TRAIN
        )
        loss = self.compute_objectives(predictions, targets)

        if self.hparams.threshold_byloss:
            th = self.hparams.threshold
            loss = loss[loss > th]
            if loss.nelement() > 0:
                loss = loss.mean()
        else:
            loss = loss.mean()

        if (
            loss.nelement() > 0 and loss < self.hparams.loss_upper_lim
        ):  # the fix for computational problems
            loss.backward()
            if self.hparams.clip_grad_norm >= 0:
                torch.nn.utils.clip_grad_norm_(
                    self.modules.parameters(),
                    self.hparams.clip_grad_norm,
                )
            self.optimizer.step()
        else:
            self.nonfinite_count += 1
            logger.info(
                "infinite loss or empty loss! it happened {} times so far - skipping this batch".format(
                    self.nonfinite_count
                )
            )
            loss.data = torch.tensor(0.0).to(self.device)
        self.optimizer.zero_grad()

        return loss.detach().cpu()

    def evaluate_batch(self, batch, stage):
        """Computations needed for validation/test batches"""
        snt_id = batch.track_id
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig]

        with torch.no_grad():
            predictions, targets = self.compute_forward(mixture, targets, stage)
            loss = self.compute_objectives(predictions, targets)

        # Manage audio file saving
        if stage == sb.Stage.TEST and self.hparams.save_audio:
            if hasattr(self.hparams, "n_audio_to_save"):
                if self.hparams.n_audio_to_save > 0:
                    self.save_audio(snt_id[0], mixture, targets, predictions)
                    self.hparams.n_audio_to_save += -1
            else:
                self.save_audio(snt_id[0], mixture, targets, predictions)

        return loss.mean().detach()

    def on_stage_end(self, stage, stage_loss, epoch):
        """Gets called at the end of a epoch."""
        # Compute/store important stats
        stage_stats = {"si-snr": stage_loss}
        if stage == sb.Stage.TRAIN:
            self.train_stats = stage_stats

        # Perform end-of-iteration things, like annealing, logging, etc.
        if stage == sb.Stage.VALID:
            # Learning rate annealing
            if isinstance(
                self.hparams.lr_scheduler, schedulers.ReduceLROnPlateau
            ):
                current_lr, next_lr = self.hparams.lr_scheduler(
                    [self.optimizer], epoch, stage_loss
                )
                schedulers.update_learning_rate(self.optimizer, next_lr)
            else:
                # if we do not use the reducelronplateau, we do not change the lr
                current_lr = self.hparams.optimizer.optim.param_groups[0]["lr"]

            self.hparams.train_logger.log_stats(
                stats_meta={"epoch": epoch, "lr": current_lr},
                train_stats=self.train_stats,
                valid_stats=stage_stats,
            )
            self.checkpointer.save_and_keep_only(
                meta={"si-snr": stage_stats["si-snr"]}, min_keys=["si-snr"]
            )
        elif stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                stats_meta={"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stage_stats,
            )


    

    def save_results(self, test_loader):
        """This script computes the SDR and SI-SNR metrics and saves
        them into a csv file"""

        # This package is required for SDR computation
        from mir_eval.separation import bss_eval_sources

        # Create folders where to store audio
        save_file = os.path.join(self.hparams.output_folder, "test_results.csv")

        # Variable init
        all_sdrs = []
        all_sdrs_i = []
        all_sisnrs = []
        all_sisnrs_i = []
        csv_columns = ["snt_id", "sdr", "sdr_i", "si-snr", "si-snr_i"]


        def is_silent(source, threshold=1e-6):
            return np.max(np.abs(source[0])) < threshold or np.max(np.abs(source[1])) < threshold

        with open(save_file, "w", newline="", encoding="utf-8") as results_csv:
            writer = csv.DictWriter(results_csv, fieldnames=csv_columns)
            writer.writeheader()
            skip_cnt = 0

            # Loop over all test sentence
            with tqdm(test_loader, dynamic_ncols=True) as t:
                for i, batch in enumerate(t):
                    # Apply Separation
                    mixture, mix_len = batch.mix_sig
                    snt_id = batch.track_id
                    targets = [batch.voc_sig, batch.inst_sig]
                   

                    with torch.no_grad():
                        predictions, targets = self.compute_forward(
                            batch.mix_sig, targets, sb.Stage.TEST
                        )

                    # Compute SI-SNR
                    sisnr = self.compute_objectives(predictions, targets)

                    # Compute SI-SNR improvement
                    mixture_signal = torch.stack(
                        [mixture] * self.hparams.num_sources, dim=-1
                    )
                    mixture_signal = mixture_signal.to(targets.device)
                    sisnr_baseline = self.compute_objectives(
                        mixture_signal, targets
                    )
                    sisnr_i = sisnr - sisnr_baseline
                    
     
                    if not is_silent(targets[0].t().cpu().numpy()) and not is_silent(predictions[0].t().detach().cpu().numpy()) and not is_silent(mixture_signal[0].t().detach().cpu().numpy()):
                        
                    
                        sdr, _, _, _ = bss_eval_sources(
                            targets[0].t().cpu().numpy(),
                            predictions[0].t().detach().cpu().numpy(),
                            compute_permutation=False
                        )
    
                        sdr_baseline, _, _, _ = bss_eval_sources(
                            targets[0].t().cpu().numpy(),
                            mixture_signal[0].t().detach().cpu().numpy(),
                            compute_permutation=False
                        )
    
                        sdr_i = sdr.mean() - sdr_baseline.mean()
    
                        # Saving on a csv file
                        row = {
                            "snt_id": snt_id[0],
                            "sdr": sdr.mean(),
                            "sdr_i": sdr_i,
                            "si-snr": -sisnr.item(),
                            "si-snr_i": -sisnr_i.item(),
                        }
                        writer.writerow(row)
    
                        # Metric Accumulation
                        all_sdrs.append(sdr.mean())
                        all_sdrs_i.append(sdr_i.mean())
                        all_sisnrs.append(-sisnr.item())
                        all_sisnrs_i.append(-sisnr_i.item())
    
                    
                else:
                    skip_cnt += 1
                    print(f"Warning: skipping silent target, this has happened {skip_cnt} times")
                row = {
                    "snt_id": "avg",
                    "sdr": np.array(all_sdrs).mean(),
                    "sdr_i": np.array(all_sdrs_i).mean(),
                    "si-snr": np.array(all_sisnrs).mean(),
                    "si-snr_i": np.array(all_sisnrs_i).mean(),
                }
                writer.writerow(row)

        logger.info("Mean SISNR is {}".format(np.array(all_sisnrs).mean()))
        logger.info("Mean SISNRi is {}".format(np.array(all_sisnrs_i).mean()))
        logger.info("Mean SDR is {}".format(np.array(all_sdrs).mean()))
        logger.info("Mean SDRi is {}".format(np.array(all_sdrs_i).mean()))

        # Write to the metrics file
        if(self.hparams.result_file_path is not None and self.hparams.result_file_path != ""):
            with open(self.hparams.result_file_path, "a", newline="", encoding="utf-8") as metrics_csv:
                writer = csv.DictWriter(metrics_csv, fieldnames=["model_name", "n_epochs", "learning_rate", "chunk_size", "sample_rate", "sdr", "sdr_i", "si-snr", "si-snr_i"])
                row = {
                        "model_name": self.hparams.experiment_name,
                        "learning_rate": self.hparams.lr,
                        "n_epochs": self.hparams.N_epochs,
                        "chunk_size":self.hparams.chunk_size,
                        "sample_rate":self.hparams.sample_rate,
                        "sdr": np.array(all_sdrs).mean(),
                        "sdr_i": np.array(all_sdrs_i).mean(),
                        "si-snr": np.array(all_sisnrs).mean(),
                        "si-snr_i": np.array(all_sisnrs_i).mean(),
                    }
                writer.writerow(row)

    def save_audio(self, snt_id, mixture, targets, predictions):
        "saves the test audio (mixture, targets, and estimated sources) on disk"

        # Create output folder
        save_path = os.path.join(self.hparams.save_folder, "audio_results")
        if not os.path.exists(save_path):
            os.mkdir(save_path)

        for ns in range(self.hparams.num_sources):
            # Estimated source
            signal = predictions[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}hat.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

            # Original source
            signal = targets[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

        # Mixture
        signal = mixture[0][0, :]
        signal = signal / signal.abs().max()
        save_file = os.path.join(save_path, "item{}_mix.wav".format(snt_id))
        torchaudio.save(
            save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
        )





if __name__ == "__main__":
    # Load hyperparameters file with command-line overrides
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])
    with open(hparams_file, encoding="utf-8") as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Initialize ddp (useful only for multi-GPU DDP training)
    sb.utils.distributed.ddp_init_group(run_opts)

    # Logger info
    logger = get_logger(__name__)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Update precision to bf16 if the device is CPU and precision is fp16
    if run_opts.get("device") == "cpu" and hparams.get("precision") == "fp16":
        hparams["precision"] = "bf16"

   

    # Brain class initialization
    separator = Separation(
        modules=hparams["modules"],
        opt_class=hparams["optimizer"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )
 
    # Training
        
    # Usage with SpeechBrain
    train_data = MusDBDataset(hparams["db_path"], subset="train", split="train", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    valid_data = MusDBDataset(hparams["db_path"], subset="train", split="valid", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    test_data = MusDBDataset(hparams["db_path"], subset="test", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    

    # Create DataLoader
    train_loader = sb.dataio.dataloader.make_dataloader(
        train_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    valid_loader = sb.dataio.dataloader.make_dataloader(
        valid_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    test_loader = sb.dataio.dataloader.make_dataloader(
        test_data,
        batch_size=hparams["batch_size"],
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )
    
    separator.fit(
        separator.hparams.epoch_counter,
        train_loader,
        valid_loader,
        train_loader_kwargs=hparams["dataloader_opts"],
        valid_loader_kwargs=hparams["dataloader_opts"],
    )

    # # Eval
    separator.evaluate(test_loader, min_key="si-snr")
    separator.save_results(test_loader)
# Out:
# Overwriting sepformer-train.py

# %%
# !python sepformer-train.py sepformer-hparams.yaml --data_folder=db_path
# !torchrun --standalone --nproc_per_node=2 sepformer-train.py sepformer-hparams.yaml --data_folder={db_path} --result_file_path={result_file_path}
# Out:
# W0420 14:49:12.161000 112550 torch/distributed/run.py:793]
# W0420 14:49:12.161000 112550 torch/distributed/run.py:793] *****************************************
# W0420 14:49:12.161000 112550 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0420 14:49:12.161000 112550 torch/distributed/run.py:793] *****************************************
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: /kaggle/working/results/sepformer/1234
# speechbrain.core - Info: precision arg from hparam file is used
# speechbrain.core - Info: noprogressbar arg from hparam file is used
# speechbrain.core - Gradscaler enabled: `True`
# speechbrain.core - Using training precision: `--precision=fp16`
# speechbrain.core - Using evaluation precision: `--eval_precision=fp32`
# speechbrain.core - Separation Model Statistics:
# * Total Number of Trainable Parameters: 6.7M
# * Total Number of Parameters: 6.7M
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+01-17-47+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100%|██████████████████████████| 81/81 [14:43<00:00, 10.91s/it, train_loss=4.95]
# 100%|███████████████████████████████████████████| 13/13 [02:38<00:00, 12.16s/it]
# speechbrain.utils.train_logger - epoch: 21, lr: 1.50e-04 - train si-snr: 4.95 - valid si-snr: 6.25
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-06-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+01-17-47+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100%|██████████████████████████| 81/81 [14:37<00:00, 10.83s/it, train_loss=5.01]
# 100%|███████████████████████████████████████████| 13/13 [02:31<00:00, 11.62s/it]
# speechbrain.utils.train_logger - epoch: 22, lr: 1.50e-04 - train si-snr: 5.01 - valid si-snr: 6.40
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-24-05+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-06-56+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100%|██████████████████████████| 81/81 [14:48<00:00, 10.97s/it, train_loss=4.33]
# 100%|███████████████████████████████████████████| 13/13 [02:35<00:00, 11.92s/it]
# speechbrain.utils.train_logger - epoch: 23, lr: 1.50e-04 - train si-snr: 4.33 - valid si-snr: 6.61
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-41-29+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-24-05+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100%|██████████████████████████| 81/81 [14:54<00:00, 11.04s/it, train_loss=4.68]
# 100%|███████████████████████████████████████████| 13/13 [02:32<00:00, 11.76s/it]
# speechbrain.utils.train_logger - epoch: 24, lr: 1.50e-04 - train si-snr: 4.68 - valid si-snr: 6.54
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-58-56+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-41-29+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100%|███████████████████████████| 81/81 [14:49<00:00, 10.98s/it, train_loss=4.4]
# 100%|███████████████████████████████████████████| 13/13 [02:37<00:00, 12.11s/it]
# speechbrain.utils.train_logger - epoch: 25, lr: 1.50e-04 - train si-snr: 4.40 - valid si-snr: 6.75
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+16-16-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+15-58-56+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100%|██████████████████████████| 81/81 [14:47<00:00, 10.96s/it, train_loss=4.46]
# 100%|███████████████████████████████████████████| 13/13 [02:34<00:00, 11.87s/it]
# speechbrain.utils.train_logger - epoch: 26, lr: 1.50e-04 - train si-snr: 4.46 - valid si-snr: 5.70
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+16-33-45+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+16-16-23+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-19+23-03-35+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100%|██████████████████████████| 81/81 [14:44<00:00, 10.92s/it, train_loss=4.43]
# 100%|███████████████████████████████████████████| 13/13 [02:30<00:00, 11.59s/it]
# speechbrain.utils.train_logger - epoch: 27, lr: 1.50e-04 - train si-snr: 4.43 - valid si-snr: 5.82
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+16-51-00+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100%|███████████████████████████| 81/81 [14:46<00:00, 10.94s/it, train_loss=4.3]
# 100%|███████████████████████████████████████████| 13/13 [02:34<00:00, 11.90s/it]
# speechbrain.utils.train_logger - epoch: 28, lr: 1.50e-04 - train si-snr: 4.30 - valid si-snr: 5.64
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+16-51-00+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+16-33-45+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100%|██████████████████████████| 81/81 [14:46<00:00, 10.95s/it, train_loss=3.66]
# 100%|███████████████████████████████████████████| 13/13 [02:32<00:00, 11.72s/it]
# speechbrain.utils.train_logger - epoch: 29, lr: 1.50e-04 - train si-snr: 3.66 - valid si-snr: 6.37
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-25-41+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100%|██████████████████████████| 81/81 [14:59<00:00, 11.10s/it, train_loss=3.99]
# 100%|███████████████████████████████████████████| 13/13 [02:35<00:00, 11.98s/it]
# speechbrain.utils.train_logger - epoch: 30, lr: 1.50e-04 - train si-snr: 3.99 - valid si-snr: 5.78
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-25-41+00
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# /usr/local/lib/python3.11/dist-packages/speechbrain/nnet/schedulers.py:992: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(path)
# 100%|███████████████████████████████████████████| 44/44 [08:35<00:00, 11.71s/it]
# speechbrain.utils.train_logger - Epoch loaded: 28 - test si-snr: 9.49
#   0%|                                                    | 0/44 [00:00<?, ?it/s]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:11<07:53, 11.01s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:11<08:04, 11.27s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:21<07:32, 10.78s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:22<07:40, 10.97s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:32<07:26, 10.89s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:33<07:33, 11.07s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:48<08:39, 12.99s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:49<08:39, 13.00s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [00:59<07:58, 12.27s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [01:00<07:59, 12.30s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  14%|██████                                      | 6/44 [01:10<07:29, 11.82s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  16%|███████                                     | 7/44 [01:23<07:29, 12.14s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  18%|████████                                    | 8/44 [01:35<07:17, 12.14s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  23%|█████████▊                                 | 10/44 [01:57<06:18, 11.14s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  25%|██████████▊                                | 11/44 [02:06<05:55, 10.76s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  32%|█████████████▋                             | 14/44 [02:50<06:41, 13.40s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  34%|██████████████▋                            | 15/44 [02:58<05:42, 11.81s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  36%|███████████████▋                           | 16/44 [03:11<05:40, 12.15s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:22<05:17, 11.74s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:22<05:18, 11.81s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  41%|█████████████████▌                         | 18/44 [03:34<05:14, 12.11s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  43%|██████████████████▌                        | 19/44 [03:44<04:40, 11.23s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [03:56<04:32, 11.34s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [04:09<04:33, 11.90s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [04:09<04:35, 11.99s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:24<04:42, 12.83s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:24<04:43, 12.91s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:33<04:05, 11.71s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:33<04:06, 11.73s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [04:39<03:18,  9.95s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [04:39<03:19,  9.98s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [04:50<03:17, 10.42s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [04:51<03:18, 10.45s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#  59%|█████████████████████████▍                 | 26/44 [05:01<03:10, 10.58s/it]/kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  61%|██████████████████████████▍                | 27/44 [05:15<03:13, 11.38s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  66%|████████████████████████████▎              | 29/44 [05:40<02:59, 12.00s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [05:52<02:48, 12.05s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  73%|███████████████████████████████▎           | 32/44 [06:18<02:33, 12.75s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [06:30<02:17, 12.51s/it]/kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [06:30<02:17, 12.53s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [06:44<02:09, 12.92s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [06:44<02:10, 13.10s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [06:59<02:02, 13.56s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [06:59<02:02, 13.63s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [07:11<01:44, 13.06s/it]/kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [07:11<01:44, 13.08s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#  84%|████████████████████████████████████▏      | 37/44 [07:23<01:29, 12.75s/it]/kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  86%|█████████████████████████████████████▏     | 38/44 [07:34<01:13, 12.31s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [07:49<01:05, 13.14s/it]/kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [07:49<01:05, 13.10s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [08:02<00:51, 12.86s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [08:11<00:35, 11.80s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
#  95%|█████████████████████████████████████████  | 42/44 [08:23<00:23, 11.80s/it]/kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  98%|██████████████████████████████████████████ | 43/44 [08:32<00:11, 11.16s/it]/kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:251: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# /kaggle/working/sepformer-train.py:257: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [08:44<00:00, 11.93s/it]
# Warning: skipping silent target, this has happened 1 times
# __main__ - Mean SISNR is 0.020531462084862492
# __main__ - Mean SISNRi is 1.7149834786691973
# __main__ - Mean SDR is -7.789682055931547
# __main__ - Mean SDRi is -8.53428999304211
# 100%|███████████████████████████████████████████| 44/44 [08:45<00:00, 11.94s/it]
# Warning: skipping silent target, this has happened 1 times
# [rank0]:[W420 18:00:37.226859558 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %% [markdown]
# ## Demucs v2 (Music Source Separation in the Waveform Domain)
#
# **Key Idea**
# Demucs v2 is a waveform-to-waveform U-Net model designed for music source separation, leveraging bidirectional LSTMs and time-domain convolutions to outperform spectrogram-based methods. It introduces pitch/tempo augmentation and overlap-add reconstruction to reduce artifacts at segment boundaries 102.
#
# **Architecture**
# - Encoder: Strided 1D convolutions to compress the waveform into latent features.
# - Decoder: Transposed convolutions to reconstruct separated stems (drums, bass, vocals, etc.).
# - Bidirectional LSTM: Bridges the encoder and decoder to capture long-term dependencies.
#
# ![image.png](attachment:80b106ae-6178-471d-afed-cc69da63ba61.png)
#
#
# Source: https://github.com/facebookresearch/demucs/tree/v2
#
# **Advantages**
# - State-of-the-Art SDR: Achieves 6.3 dB on MUSDB (vs. 5.7 dB for Conv-Tasnet) without extra data 10.
# - Natural Sounding Output: Human evaluations (MOS 3.2) favor Demucs over spectrogram methods 10.
#
#
# **Limitations**
# Bleeding Artifacts: Vocals often leak into other stems 10.
#
#
# **Personal Insights**
# Demucs v2’s waveform-centric approach demonstrates that time-domain models can surpass spectrogram methods when combined with LSTMs and clever augmentation. It also feels empowering to develop a 250 million parameter model.
#
# **References**
# - https://github.com/speechbrain/speechbrain/tree/develop/recipes/WSJ0Mix/separation
# - https://github.com/facebookresearch/demucs/tree/v2
# - https://github.com/f90/Wave-U-Net
# - https://hal.science/hal-02379796/document

# %%
# %%file demucsModels.py

import torch
from torch import nn
from speechbrain.nnet.CNN import Conv1d, ConvTranspose1d
# from speechbrain.nnet.activations import GLU
from speechbrain.lobes.models.beats import GLU_Linear
from torch.nn import GLU
from speechbrain.nnet.RNN import LSTM
from speechbrain.nnet.linear import Linear

class EncoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = Conv1d(
            out_channels=out_channels,
            in_channels=in_channels,
            kernel_size=8,
            stride=4,
            # default_padding=2,
            skip_transpose=True,
        )
        self.glu_conv = Conv1d(
            out_channels=2*out_channels,
            in_channels=out_channels,
            kernel_size=1,
            stride=1,
            skip_transpose=True,
        )
        self.relu = torch.nn.ReLU()
        self.glu = GLU(dim=1)

    def forward(self, x):
        x = self.relu(self.conv(x))
        x = self.glu(self.glu_conv(x))
        return x

class DecoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.glu_conv = Conv1d(
            out_channels=2*in_channels,
            in_channels=in_channels,
            kernel_size=1,
            stride=1,
            skip_transpose=True,
        )
        self.conv_tr = ConvTranspose1d(
            out_channels=out_channels,
            in_channels=in_channels,  # After GLU split
            kernel_size=8,
            stride=4,
            skip_transpose=True,
        )
        self.glu = GLU(dim=1)
        self.relu = torch.nn.ReLU()

    def forward(self, x, skip=None):

        if skip is not None:

            # T changed after conv1d in encoder, fix it here
            T_x = x.size(-1)
            T_skip = skip.size(-1)
            
            if T_skip > T_x:
                skip = skip[..., :T_x]  
            elif T_skip < T_x:
                pad = T_x - T_skip
                skip = nn.functional.pad(skip, (0, pad))
                
            x = x + skip


        x = self.glu(self.glu_conv(x))
        x = self.relu(self.conv_tr(x))
        return x




class SourceSeparator(nn.Module):
    def __init__(self, in_channels, out_channels=2, num_sources=4):
        """
        Args:
            C_in: Input channels from last decoder (typically 8)
            C_out: Output channels per source (2 for stereo)
            num_sources: Number of sources to separate (e.g. 4 for vocals, drums, bass, other)
        """
        super().__init__()
        # Final linear layer (no activation)
        self.output_proj = Linear(
            input_size=in_channels,
            n_neurons=num_sources * out_channels,  # 4 sources * 2 channels = 8
            bias=True
        )
        self.num_sources = num_sources
        self.out_channels = out_channels

    def forward(self, x):
        """
        Input: [batch, C_in, time]
        Output: [batch, num_sources, out_channels, time]
        """
        # Permute to [batch, time, features]
        
        x = x.permute(0, 2, 1)

        # Project to source waveforms
        x = self.output_proj(x)  # [batch, time, num_sources*out_channels]
        
        x = x.permute(0, 2, 1)
        
        return x
# Out:
# Overwriting demucsModels.py

# %%
# %%file demucs-hparams.yaml
#
# # ################################
# # Model: Demucs for source separation
# # https://hal.science/hal-02379796/document
# # Dataset : Musdb
# # ################################
# # Basic parameters
# seed: 1234
# __set_seed: !apply:speechbrain.utils.seed_everything [!ref <seed>]
#
# # Data params
# data_folder: !PLACEHOLDER
#
# experiment_name: demucs
# output_folder: !ref /kaggle/working/results/<experiment_name>/<seed>
# train_log: !ref <output_folder>/train_log.txt
# save_folder: !ref <output_folder>/save
# train_data: !ref <output_folder>/train.json
# valid_data: !ref <output_folder>/valid.json
# test_data: !ref <output_folder>/test.json
# skip_prep: False
#
# # Manually Set This
# db_path: '/kaggle/input/musdb18-music-source-separation-dataset'
#
# result_file_path: !PLACEHOLDER
#
# # Experiment params
# precision: fp16
# num_sources: 2
#
# noprogressbar: False
# save_audio: True
# sample_rate: 16000
# n_audio_to_save: 10
# chunk_size: 10
#
# ####################### Training Parameters ####################################
#
# N_epochs: 30
# batch_size: 1
# lr: 0.0005
# clip_grad_norm: 5
# loss_upper_lim: 999999
#
#
#
#
#
# ####################### WaveDrop Params ########################################
#
# use_wavedrop: True
# # Frequency drop: randomly drops a number of frequency bands to zero.
# drop_freq_low: 0  # Min frequency band dropout probability
# drop_freq_high: 1  # Max frequency band dropout probability
# drop_freq_count_low: 1  # Min number of frequency bands to drop
# drop_freq_count_high: 3  # Max number of frequency bands to drop
# drop_freq_width: 0.05  # Width of frequency bands to drop
#
# drop_freq: !new:speechbrain.augment.time_domain.DropFreq
#     drop_freq_low: !ref <drop_freq_low>
#     drop_freq_high: !ref <drop_freq_high>
#     drop_freq_count_low: !ref <drop_freq_count_low>
#     drop_freq_count_high: !ref <drop_freq_count_high>
#     drop_freq_width: !ref <drop_freq_width>
#
# # Time drop: randomly drops a number of temporal chunks.
# drop_chunk_count_low: 1  # Min number of audio chunks to drop
# drop_chunk_count_high: 3  # Max number of audio chunks to drop
# drop_chunk_length_low: 1000  # Min length of audio chunks to drop
# drop_chunk_length_high: 2000  # Max length of audio chunks to drop
#
# drop_chunk: !new:speechbrain.augment.time_domain.DropChunk
#     drop_length_low: !ref <drop_chunk_length_low>
#     drop_length_high: !ref <drop_chunk_length_high>
#     drop_count_low: !ref <drop_chunk_count_low>
#     drop_count_high: !ref <drop_chunk_count_high>
# threshold_byloss: True
# threshold: -30
#
#
#
# kernel_size: 16
# # kernel_stride: 8
#
# # Dataloader options
# dataloader_opts:
#     batch_size: !ref <batch_size>
#     num_workers: 3
#
# ######################## Network Definition ####################################
#
#
# Encoder1: !new:demucsModels.EncoderBlock
#     in_channels: 1
#     out_channels: 64
#
#
# Encoder2: !new:demucsModels.EncoderBlock
#     in_channels: 64
#     out_channels: 128
#
#
# Encoder3: !new:demucsModels.EncoderBlock
#     in_channels: 128
#     out_channels: 256
#
#
# Encoder4: !new:demucsModels.EncoderBlock
#     in_channels: 256
#     out_channels: 512
#
#
# Encoder5: !new:demucsModels.EncoderBlock
#     in_channels: 512
#     out_channels: 1024
#
#
# Encoder6: !new:demucsModels.EncoderBlock
#     in_channels: 1024
#     out_channels: 2048
#
#
#
#
# Decoder6: !new:demucsModels.DecoderBlock
#     in_channels: 2048
#     out_channels: 1024
#
#
# Decoder5: !new:demucsModels.DecoderBlock
#     in_channels: 1024
#     out_channels: 512
#
#
# Decoder4: !new:demucsModels.DecoderBlock
#     in_channels: 512
#     out_channels: 256
#
#
# Decoder3: !new:demucsModels.DecoderBlock
#     in_channels: 256
#     out_channels: 128
#
#
# Decoder2: !new:demucsModels.DecoderBlock
#     in_channels: 128
#     out_channels: 64
#
#
# Decoder1: !new:demucsModels.DecoderBlock
#     in_channels: 64
#     out_channels: 4
#
#
# Linear: !new:speechbrain.nnet.linear.Linear
#     input_size: 4096
#     bias: False
#     n_neurons: 2048
#
# BiLSTM: !new:speechbrain.nnet.RNN.LSTM
#     hidden_size: 2048
#     input_size: 2048
#     num_layers: 2
#     bidirectional: True
#     # batch_first: True
#
# LinearSeparator: !new:demucsModels.SourceSeparator
#     in_channels: 4
#     out_channels: 1
#     num_sources: !ref <num_sources>
#
#
# ######################## Remaining Config ######################################
# optimizer: !name:torch.optim.Adam
#     lr: !ref <lr>
#     weight_decay: 0
#
# # loss: !name:speechbrain.nnet.losses.mse_loss : another alternative
# # loss: !name:speechbrain.nnet.losses.l1_loss : as used in the demucs official paper
#
# loss: !name:speechbrain.nnet.losses.get_si_snr_with_pitwrapper
#
# lr_scheduler: !new:speechbrain.nnet.schedulers.ReduceLROnPlateau
#     factor: 0.5
#     patience: 2
#     dont_halve_until_epoch: 50
#
# epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter
#     limit: !ref <N_epochs>
#
# modules:
#     encoder1: !ref <Encoder1>
#     encoder2: !ref <Encoder2>
#     encoder3: !ref <Encoder3>
#     encoder4: !ref <Encoder4>
#     encoder5: !ref <Encoder5>
#     encoder6: !ref <Encoder6>
#     lstm: !ref <BiLSTM>
#     linear: !ref <Linear>
#     decoder6: !ref <Decoder6>
#     decoder5: !ref <Decoder5>
#     decoder4: !ref <Decoder4>
#     decoder3: !ref <Decoder3>
#     decoder2: !ref <Decoder2>
#     decoder1: !ref <Decoder1>
#     linearSeparator: !ref <LinearSeparator>
#
# checkpointer: !new:speechbrain.utils.checkpoints.Checkpointer
#     checkpoints_dir: !ref <save_folder>
#     recoverables:
#         encoder1: !ref <Encoder1>
#         encoder2: !ref <Encoder2>
#         encoder3: !ref <Encoder3>
#         encoder4: !ref <Encoder4>
#         encoder5: !ref <Encoder5>
#         encoder6: !ref <Encoder6>
#         lstm: !ref <BiLSTM>
#         linear: !ref <Linear>
#         decoder6: !ref <Decoder6>
#         decoder5: !ref <Decoder5>
#         decoder4: !ref <Decoder4>
#         decoder3: !ref <Decoder3>
#         decoder2: !ref <Decoder2>
#         decoder1: !ref <Decoder1>
#         linearSeparator: !ref <LinearSeparator>
#         counter: !ref <epoch_counter>
#
#
# train_logger: !new:speechbrain.utils.train_logger.FileTrainLogger
#     save_file: !ref <train_log>
# Out:
# Overwriting demucs-hparams.yaml

# %%
# %%file demucs-train.py
#!/usr/bin/env/python3
"""Recipe for training a neural speech separation system on the wsjmix
dataset. The system employs an encoder, a decoder, and a masking network.

To run this recipe, do the following:
> python train.py hparams/sepformer.yaml
> python train.py hparams/dualpath_rnn.yaml
> python train.py hparams/convtasnet.yaml

The experiment file is flexible enough to support different neural
networks. By properly changing the parameter files, you can try
different architectures. The script supports both wsj2mix and
wsj3mix.


Authors
 * Cem Subakan 2020
 * Mirco Ravanelli 2020
 * Samuele Cornell 2020
 * Mirko Bronzi 2020
 * Jianyuan Zhong 2020
"""
## CHECKPOINT
import csv
import os
import sys

import numpy as np
import torch
import torch.nn.functional as F
import torchaudio
from hyperpyyaml import load_hyperpyyaml
from tqdm import tqdm



import speechbrain as sb
import speechbrain.nnet.schedulers as schedulers
from speechbrain.utils.distributed import run_on_main
from speechbrain.utils.logger import get_logger
from speechbrain.nnet.CNN import Conv1d, ConvTranspose1d
# from speechbrain.nnet.activations import GLU
from speechbrain.lobes.models.beats import GLU_Linear
from torch.nn import GLU
from speechbrain.nnet.RNN import LSTM
from speechbrain.nnet.linear import Linear
from demucsModels import EncoderBlock, DecoderBlock
from speechbrain.nnet.losses import get_si_snr_with_pitwrapper
from dataset import MusDBDataset

from torch.utils.data import Dataset
import musdb
np.float_ = np.float64





# Define training procedure
class DemucsSeparation(sb.Brain):
   


    def compute_forward(self, mix, targets, stage, noise=None):
        """Forward computations from the mixture to the separated signals."""

        # Unpack lists and put tensors in the right device
        mix, mix_lens = mix
        mix, mix_lens = mix.to(self.device), mix_lens.to(self.device)

        # Convert targets to tensor
        
        targets = torch.cat(
            [targets[i][0].unsqueeze(-1) for i in range(self.hparams.num_sources)],
            dim=-1,
        ).to(self.device)

        if stage == sb.Stage.TRAIN:
            with torch.no_grad():
                if self.hparams.use_wavedrop:
                    mix = self.hparams.drop_chunk(mix, mix_lens)
                    mix = self.hparams.drop_freq(mix)
        
        mix=mix.unsqueeze(1)
        targets=targets.permute(0,2,1)
       

        mix_enc_1 = self.modules.encoder1(mix)
        mix_enc_2 = self.modules.encoder2(mix_enc_1)
        mix_enc_3 = self.modules.encoder3(mix_enc_2)
        mix_enc_4 = self.modules.encoder4(mix_enc_3)
        mix_enc_5 = self.modules.encoder5(mix_enc_4)
        mix_enc_6 = self.modules.encoder6(mix_enc_5)

        lstm_in = mix_enc_6.permute(0,2,1)
        lstm_out, _ = self.modules.lstm(lstm_in) # outputs both -- outputs as well as hidden states -- we dont need hidden states
        lin_out = self.modules.linear(lstm_out)
        lin_out = lin_out.permute(0,2,1)

        mix_dec_6 = self.modules.decoder6(lin_out, skip=mix_enc_6)
        mix_dec_5 = self.modules.decoder5(mix_dec_6, skip=mix_enc_5)
        mix_dec_4 = self.modules.decoder4(mix_dec_5, skip=mix_enc_4)
        mix_dec_3 = self.modules.decoder3(mix_dec_4, skip=mix_enc_3)
        mix_dec_2 = self.modules.decoder2(mix_dec_3, skip=mix_enc_2)
        mix_dec_1 = self.modules.decoder1(mix_dec_2, skip=mix_enc_1)

        mix_out = self.modules.linearSeparator(mix_dec_1)
        est_source = mix_out



        # T changed after conv1d in encoder, fix it here
        T_origin = targets.size(2)
        T_est = est_source.size(2)

        if T_origin > T_est:
            est_source = F.pad(est_source, (0, 0, T_origin - T_est))
        else:
            est_source = est_source[:, : , :T_origin]

        return est_source, targets

    def compute_objectives(self, predictions, targets):
        """Computes the sinr loss"""
        
        targets = targets.permute(0,2,1)
        predictions = predictions.permute(0,2,1)
        return self.hparams.loss(targets, predictions) # for pitwrapper loss
## CHECKPOINT
    def fit_batch(self, batch):
        """Trains one batch"""

        # Unpacking batch list
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig]

        with self.training_ctx:
            predictions, targets = self.compute_forward(
                mixture, targets, sb.Stage.TRAIN
            )

            loss = self.compute_objectives(predictions, targets)

            # hard threshold the easy dataitems
            if self.hparams.threshold_byloss:
                th = self.hparams.threshold
                loss = loss[loss > th]
                if loss.nelement() > 0:
                    loss = loss.mean()
            else:
                loss = loss.mean()

        # loss threshold and clipping
        if loss.nelement() > 0 and loss < self.hparams.loss_upper_lim:
            self.scaler.scale(loss).backward()
            if self.hparams.clip_grad_norm >= 0:
                self.scaler.unscale_(self.optimizer)
                torch.nn.utils.clip_grad_norm_(
                    self.modules.parameters(),
                    self.hparams.clip_grad_norm,
                )
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            self.nonfinite_count += 1
            logger.info(
                "infinite loss or empty loss! it happened {} times so far - skipping this batch".format(
                    self.nonfinite_count
                )
            )
            loss.data = torch.tensor(0.0).to(self.device)
        self.optimizer.zero_grad()

        return loss.detach().cpu()

    def evaluate_batch(self, batch, stage):
        """Computations needed for validation/test batches"""
        snt_id = batch.track_id
        mixture = batch.mix_sig
        targets = [batch.voc_sig, batch.inst_sig]


        with torch.no_grad():
            predictions, targets = self.compute_forward(mixture, targets, stage)
            loss = self.compute_objectives(predictions, targets)

        # Manage audio file saving
        if stage == sb.Stage.TEST and self.hparams.save_audio:
            if hasattr(self.hparams, "n_audio_to_save"):
                if self.hparams.n_audio_to_save > 0:
                    self.save_audio(snt_id, mixture, targets, predictions)
                    self.hparams.n_audio_to_save += -1
            else:
                self.save_audio(snt_id, mixture, targets, predictions)

        return loss.mean().detach()

    def on_stage_end(self, stage, stage_loss, epoch):
        """Gets called at the end of a epoch."""
        # Compute/store important stats
        stage_stats = {"si-snr": stage_loss}
        if stage == sb.Stage.TRAIN:
            self.train_stats = stage_stats

        # Perform end-of-iteration things, like annealing, logging, etc.
        if stage == sb.Stage.VALID:
            # Learning rate annealing
            if isinstance(
                self.hparams.lr_scheduler, schedulers.ReduceLROnPlateau
            ):
                current_lr, next_lr = self.hparams.lr_scheduler(
                    [self.optimizer], epoch, stage_loss
                )
                schedulers.update_learning_rate(self.optimizer, next_lr)
            else:
                # if we do not use the reducelronplateau, we do not change the lr
                current_lr = self.hparams.optimizer.optim.param_groups[0]["lr"]

            self.hparams.train_logger.log_stats(
                stats_meta={"epoch": epoch, "lr": current_lr},
                train_stats=self.train_stats,
                valid_stats=stage_stats,
            )
            self.checkpointer.save_and_keep_only(
                meta={"si-snr": stage_stats["si-snr"]}, min_keys=["si-snr"]
            )
        elif stage == sb.Stage.TEST:
            self.hparams.train_logger.log_stats(
                stats_meta={"Epoch loaded": self.hparams.epoch_counter.current},
                test_stats=stage_stats,
            )


    def save_results(self, test_loader):
        """This script computes the SDR and SI-SNR metrics and saves
        them into a csv file"""

        # This package is required for SDR computation
        from mir_eval.separation import bss_eval_sources

        # Create folders where to store audio
        save_file = os.path.join(self.hparams.output_folder, "test_results.csv")

        # Variable init
        all_sdrs = []
        all_sdrs_i = []
        all_sisnrs = []
        all_sisnrs_i = []
        csv_columns = ["snt_id", "sdr", "sdr_i", "si-snr", "si-snr_i"]

      

        with open(save_file, "w", newline="", encoding="utf-8") as results_csv:
            writer = csv.DictWriter(results_csv, fieldnames=csv_columns)
            writer.writeheader()

            # Loop over all test sentence
            with tqdm(test_loader, dynamic_ncols=True) as t:
                for i, batch in enumerate(t):
                    # Apply Separation
                    mixture, mix_len = batch.mix_sig
                    snt_id = batch.track_id
                    targets = [batch.voc_sig, batch.inst_sig]


                    with torch.no_grad():
                        predictions, targets = self.compute_forward(
                            batch.mix_sig, targets, sb.Stage.TEST
                        )

                    # Compute SI-SNR
                    predictions = predictions.permute(0,2,1)
                    targets = targets.permute(0,2,1)
                   
                    # sisnr = self.compute_objectives(predictions, targets)
                    sisnr = get_si_snr_with_pitwrapper(predictions,targets)

                    # Compute SI-SNR improvement
                    mixture_signal = torch.stack(
                        [mixture] * self.hparams.num_sources, dim=-1
                    )

                    mixture_signal = mixture_signal.to(targets.device)
                    # sisnr_baseline = self.compute_objectives(
                    #     mixture_signal, targets
                    # )
                    sisnr_baseline = get_si_snr_with_pitwrapper(mixture_signal, targets)
                    sisnr_i = sisnr - sisnr_baseline

                    # Compute SDR
                    sdr, _, _, _ = bss_eval_sources(
                        targets[0].mean(dim=1).t().cpu().numpy(),
                        predictions[0].mean(dim=1).t().detach().cpu().numpy(),
                    )

                    sdr_baseline, _, _, _ = bss_eval_sources(
                        targets[0].mean(dim=1).t().cpu().numpy(),
                        mixture_signal[0].mean(dim=1).t().detach().cpu().numpy(),
                    )

                    sdr_i = sdr.mean() - sdr_baseline.mean()

                    # Saving on a csv file
                    row = {
                        "snt_id": snt_id[0],
                        "sdr": sdr.mean(),
                        "sdr_i": sdr_i,
                        "si-snr": -sisnr.item(),
                        "si-snr_i": -sisnr_i.item(),
                    }
                    writer.writerow(row)

                    # Metric Accumulation
                    all_sdrs.append(sdr.mean())
                    all_sdrs_i.append(sdr_i.mean())
                    all_sisnrs.append(-sisnr.item())
                    all_sisnrs_i.append(-sisnr_i.item())

                row = {
                    "snt_id": "avg",
                    "sdr": np.array(all_sdrs).mean(),
                    "sdr_i": np.array(all_sdrs_i).mean(),
                    "si-snr": np.array(all_sisnrs).mean(),
                    "si-snr_i": np.array(all_sisnrs_i).mean(),
                }
                writer.writerow(row)

        logger.info("Mean SISNR is {}".format(np.array(all_sisnrs).mean()))
        logger.info("Mean SISNRi is {}".format(np.array(all_sisnrs_i).mean()))
        logger.info("Mean SDR is {}".format(np.array(all_sdrs).mean()))
        logger.info("Mean SDRi is {}".format(np.array(all_sdrs_i).mean()))

        # save to metrics file if provided
        if(self.hparams.result_file_path is not None and self.hparams.result_file_path != ""):
            with open(self.hparams.result_file_path, "a", newline="", encoding="utf-8") as metrics_csv:
                writer = csv.DictWriter(metrics_csv, fieldnames=["model_name", "n_epochs", "learning_rate", "chunk_size", "sample_rate", "sdr", "sdr_i", "si-snr", "si-snr_i"])
                row = {
                        "model_name": self.hparams.experiment_name,
                        "learning_rate": self.hparams.lr,
                        "n_epochs": self.hparams.N_epochs,
                        "chunk_size":self.hparams.chunk_size,
                        "sample_rate":self.hparams.sample_rate,
                        "sdr": np.array(all_sdrs).mean(),
                        "sdr_i": np.array(all_sdrs_i).mean(),
                        "si-snr": np.array(all_sisnrs).mean(),
                        "si-snr_i": np.array(all_sisnrs_i).mean(),
                    }
                writer.writerow(row)

    def save_audio(self, snt_id, mixture, targets, predictions):
        "saves the test audio (mixture, targets, and estimated sources) on disk"

        # Create output folder

        save_path = os.path.join(self.hparams.save_folder, "audio_results")
        if not os.path.exists(save_path):
            os.mkdir(save_path)
        perm_targets = targets.permute(0,2,1)
        perm_predictions = predictions.permute(0,2,1)
        for ns in range(self.hparams.num_sources):
            
            
            
            signal = perm_predictions[0, :, ns]
           
            signal = signal / signal.abs().max()
           
           
            save_file = os.path.join(
                save_path, "item{}_source{}hat.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

            # Original source
            signal = perm_targets[0, :, ns]
            signal = signal / signal.abs().max()
            save_file = os.path.join(
                save_path, "item{}_source{}.wav".format(snt_id, ns + 1)
            )
            torchaudio.save(
                save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
            )

        # Mixture
        signal = mixture[0][0, :]
        signal = signal / signal.abs().max()
        save_file = os.path.join(save_path, "item{}_mix.wav".format(snt_id))
        torchaudio.save(
            save_file, signal.unsqueeze(0).cpu(), self.hparams.sample_rate
        )



if __name__ == "__main__":
    # Load hyperparameters file with command-line overrides
    hparams_file, run_opts, overrides = sb.parse_arguments(sys.argv[1:])
    with open(hparams_file, encoding="utf-8") as fin:
        hparams = load_hyperpyyaml(fin, overrides)

    # Initialize ddp (useful only for multi-GPU DDP training)
    sb.utils.distributed.ddp_init_group(run_opts)

    # Logger info
    logger = get_logger(__name__)

    # Create experiment directory
    sb.create_experiment_directory(
        experiment_directory=hparams["output_folder"],
        hyperparams_to_save=hparams_file,
        overrides=overrides,
    )

    # Update precision to bf16 if the device is CPU and precision is fp16
    if run_opts.get("device") == "cpu" and hparams.get("precision") == "fp16":
        hparams["precision"] = "bf16"



        
    train_data = MusDBDataset(hparams["db_path"], subset="train", split="train", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    valid_data = MusDBDataset(hparams["db_path"], subset="train", split="valid", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])
    test_data = MusDBDataset(hparams["db_path"], subset="test", target_sr=hparams["sample_rate"], chunk_size=hparams["chunk_size"])


    # Create DataLoader
    train_loader = sb.dataio.dataloader.make_dataloader(
        train_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    valid_loader = sb.dataio.dataloader.make_dataloader(
        valid_data,
        batch_size=hparams["batch_size"],
        shuffle=True,
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )

    test_loader = sb.dataio.dataloader.make_dataloader(
        test_data,
        batch_size=hparams["batch_size"],
        collate_fn=sb.dataio.batch.PaddedBatch  # Handles variable lengths
    )


    # Brain class initialization
    separator = DemucsSeparation(
        modules=hparams["modules"],
        opt_class=hparams["optimizer"],
        hparams=hparams,
        run_opts=run_opts,
        checkpointer=hparams["checkpointer"],
    )


    # Training
    separator.fit(
        separator.hparams.epoch_counter,
        train_loader,
        valid_loader,
        train_loader_kwargs=hparams["dataloader_opts"],
        valid_loader_kwargs=hparams["dataloader_opts"],
    )

    # Eval
    separator.evaluate(test_loader, min_key="si-snr")
    separator.save_results(test_loader)
    ## CHECKPOINT
# Out:
# Overwriting demucs-train.py

# %%
# !python3 demucs-train.py demucs-hparams.yaml --data_folder=db_path --result_file_path={result_file_path}
# !torchrun --standalone --nproc_per_node=2 demucs-train.py demucs-hparams.yaml --data_folder=db_path --result_file_path={result_file_path}
# Out:
# W0420 18:00:41.260000 236225 torch/distributed/run.py:793]
# W0420 18:00:41.260000 236225 torch/distributed/run.py:793] *****************************************
# W0420 18:00:41.260000 236225 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0420 18:00:41.260000 236225 torch/distributed/run.py:793] *****************************************
# speechbrain.utils.quirks - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# speechbrain.utils.quirks - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: /kaggle/working/results/demucs/1234
# speechbrain.core - Info: precision arg from hparam file is used
# speechbrain.core - Info: noprogressbar arg from hparam file is used
# speechbrain.core - Gradscaler enabled: `True`
# speechbrain.core - Using training precision: `--precision=fp16`
# speechbrain.core - Using evaluation precision: `--eval_precision=fp32`
# speechbrain.core - DemucsSeparation Model Statistics:
# * Total Number of Trainable Parameters: 243.3M
# * Total Number of Parameters: 243.3M
# * Trainable Parameters represent 100.0000% of the total size.
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+05-01-40+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# speechbrain.utils.epoch_loop - Going into epoch 21
# 100%|██████████████████████████| 81/81 [14:36<00:00, 10.82s/it, train_loss=6.67]
# 100%|███████████████████████████████████████████| 13/13 [02:31<00:00, 11.69s/it]
# speechbrain.utils.train_logger - epoch: 21, lr: 5.00e-04 - train si-snr: 6.67 - valid si-snr: 6.38
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+18-18-32+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+05-01-40+00
# speechbrain.utils.epoch_loop - Going into epoch 22
# 100%|██████████████████████████| 81/81 [14:26<00:00, 10.70s/it, train_loss=6.64]
# 100%|███████████████████████████████████████████| 13/13 [02:30<00:00, 11.59s/it]
# speechbrain.utils.train_logger - epoch: 22, lr: 5.00e-04 - train si-snr: 6.64 - valid si-snr: 6.22
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+18-35-35+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+18-18-32+00
# speechbrain.utils.epoch_loop - Going into epoch 23
# 100%|██████████████████████████| 81/81 [14:26<00:00, 10.70s/it, train_loss=6.39]
# 100%|███████████████████████████████████████████| 13/13 [02:30<00:00, 11.55s/it]
# speechbrain.utils.train_logger - epoch: 23, lr: 5.00e-04 - train si-snr: 6.39 - valid si-snr: 5.93
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+18-52-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+18-35-35+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# 100%|███████████████████████████| 81/81 [14:23<00:00, 10.65s/it, train_loss=6.3]
# 100%|███████████████████████████████████████████| 13/13 [02:30<00:00, 11.58s/it]
# speechbrain.utils.train_logger - epoch: 24, lr: 5.00e-04 - train si-snr: 6.30 - valid si-snr: 6.04
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+19-09-38+00
# speechbrain.utils.epoch_loop - Going into epoch 25
# 100%|███████████████████████████| 81/81 [14:26<00:00, 10.70s/it, train_loss=6.2]
# 100%|███████████████████████████████████████████| 13/13 [02:31<00:00, 11.67s/it]
# speechbrain.utils.train_logger - epoch: 25, lr: 5.00e-04 - train si-snr: 6.20 - valid si-snr: 6.17
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+19-26-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+19-09-38+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# 100%|██████████████████████████| 81/81 [14:17<00:00, 10.59s/it, train_loss=5.56]
# 100%|███████████████████████████████████████████| 13/13 [02:30<00:00, 11.54s/it]
# speechbrain.utils.train_logger - epoch: 26, lr: 5.00e-04 - train si-snr: 5.56 - valid si-snr: 5.93
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+19-43-37+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+19-26-43+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+18-52-38+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# 100%|██████████████████████████| 81/81 [14:20<00:00, 10.62s/it, train_loss=6.42]
# 100%|███████████████████████████████████████████| 13/13 [02:29<00:00, 11.52s/it]
# speechbrain.utils.train_logger - epoch: 27, lr: 5.00e-04 - train si-snr: 6.42 - valid si-snr: 6.04
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-00-34+00
# speechbrain.utils.epoch_loop - Going into epoch 28
# 100%|██████████████████████████| 81/81 [14:23<00:00, 10.66s/it, train_loss=5.68]
# 100%|███████████████████████████████████████████| 13/13 [02:28<00:00, 11.44s/it]
# speechbrain.utils.train_logger - epoch: 28, lr: 5.00e-04 - train si-snr: 5.68 - valid si-snr: 5.82
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-17-31+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-00-34+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+19-43-37+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# 100%|██████████████████████████| 81/81 [14:17<00:00, 10.59s/it, train_loss=5.77]
# 100%|███████████████████████████████████████████| 13/13 [02:31<00:00, 11.69s/it]
# speechbrain.utils.train_logger - epoch: 29, lr: 5.00e-04 - train si-snr: 5.77 - valid si-snr: 5.84
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-34-28+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# 100%|██████████████████████████| 81/81 [14:19<00:00, 10.61s/it, train_loss=5.52]
# 100%|███████████████████████████████████████████| 13/13 [02:30<00:00, 11.58s/it]
# speechbrain.utils.train_logger - epoch: 30, lr: 5.00e-04 - train si-snr: 5.52 - valid si-snr: 5.72
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-17-31+00
# speechbrain.utils.checkpoints - Deleted checkpoint in /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-34-28+00
# speechbrain.utils.checkpoints - Loading a checkpoint from /kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.11/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# 100%|███████████████████████████████████████████| 44/44 [08:04<00:00, 11.00s/it]
# speechbrain.utils.train_logger - Epoch loaded: 30 - test si-snr: 9.73
#   0%|                                                    | 0/44 [00:00<?, ?it/s]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:09<06:59,  9.76s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   2%|█                                           | 1/44 [00:09<07:01,  9.80s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:19<06:48,  9.74s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   5%|██                                          | 2/44 [00:19<06:55,  9.90s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:29<06:47,  9.95s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   7%|███                                         | 3/44 [00:29<06:49, 10.00s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:44<07:50, 11.76s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#   9%|████                                        | 4/44 [00:44<07:47, 11.69s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [00:54<07:21, 11.33s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  11%|█████                                       | 5/44 [00:54<07:19, 11.26s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  14%|██████                                      | 6/44 [01:05<06:58, 11.01s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  14%|██████                                      | 6/44 [01:04<06:55, 10.94s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  16%|███████                                     | 7/44 [01:17<06:57, 11.28s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  16%|███████                                     | 7/44 [01:17<06:59, 11.35s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  18%|████████                                    | 8/44 [01:28<06:49, 11.39s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  18%|████████                                    | 8/44 [01:28<06:50, 11.39s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  20%|█████████                                   | 9/44 [01:40<06:39, 11.41s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  20%|█████████                                   | 9/44 [01:40<06:39, 11.41s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  23%|█████████▊                                 | 10/44 [01:48<05:54, 10.43s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  23%|█████████▊                                 | 10/44 [01:48<05:59, 10.58s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  25%|██████████▊                                | 11/44 [01:57<05:29,  9.98s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  25%|██████████▊                                | 11/44 [01:57<05:32, 10.08s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  27%|███████████▋                               | 12/44 [02:09<05:40, 10.64s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  27%|███████████▋                               | 12/44 [02:09<05:39, 10.62s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  30%|████████████▋                              | 13/44 [02:26<06:34, 12.72s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  30%|████████████▋                              | 13/44 [02:27<06:36, 12.80s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  32%|█████████████▋                             | 14/44 [02:40<06:32, 13.07s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  32%|█████████████▋                             | 14/44 [02:41<06:36, 13.21s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  34%|██████████████▋                            | 15/44 [02:48<05:27, 11.31s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  34%|██████████████▋                            | 15/44 [02:48<05:30, 11.41s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  36%|███████████████▋                           | 16/44 [03:00<05:27, 11.69s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  36%|███████████████▋                           | 16/44 [03:01<05:29, 11.77s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:11<05:05, 11.32s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  39%|████████████████▌                          | 17/44 [03:11<05:07, 11.39s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  41%|█████████████████▌                         | 18/44 [03:22<04:55, 11.37s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  41%|█████████████████▌                         | 18/44 [03:23<04:59, 11.52s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  43%|██████████████████▌                        | 19/44 [03:32<04:30, 10.81s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  43%|██████████████████▌                        | 19/44 [03:33<04:31, 10.88s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [03:42<04:19, 10.83s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  45%|███████████████████▌                       | 20/44 [03:44<04:21, 10.91s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [03:54<04:15, 11.12s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  48%|████████████████████▌                      | 21/44 [03:56<04:18, 11.22s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:08<04:24, 12.04s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  50%|█████████████████████▌                     | 22/44 [04:10<04:27, 12.18s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:16<03:46, 10.79s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  52%|██████████████████████▍                    | 23/44 [04:18<03:48, 10.88s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [04:21<03:01,  9.08s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  55%|███████████████████████▍                   | 24/44 [04:23<03:02,  9.15s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [04:32<03:01,  9.56s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  57%|████████████████████████▍                  | 25/44 [04:34<03:01,  9.57s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  59%|█████████████████████████▍                 | 26/44 [04:41<02:51,  9.50s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  59%|█████████████████████████▍                 | 26/44 [04:43<02:50,  9.49s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  61%|██████████████████████████▍                | 27/44 [04:55<02:59, 10.58s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  61%|██████████████████████████▍                | 27/44 [04:56<03:00, 10.63s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  64%|███████████████████████████▎               | 28/44 [05:07<02:59, 11.23s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  64%|███████████████████████████▎               | 28/44 [05:09<02:59, 11.23s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  66%|████████████████████████████▎              | 29/44 [05:18<02:47, 11.18s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  66%|████████████████████████████▎              | 29/44 [05:20<02:47, 11.18s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [05:29<02:36, 11.15s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  68%|█████████████████████████████▎             | 30/44 [05:31<02:35, 11.10s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  70%|██████████████████████████████▎            | 31/44 [05:38<02:15, 10.40s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  70%|██████████████████████████████▎            | 31/44 [05:39<02:14, 10.38s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  73%|███████████████████████████████▎           | 32/44 [05:53<02:22, 11.87s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  73%|███████████████████████████████▎           | 32/44 [05:55<02:22, 11.90s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [06:05<02:08, 11.70s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  75%|████████████████████████████████▎          | 33/44 [06:06<02:09, 11.79s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [06:18<02:01, 12.16s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  77%|█████████████████████████████████▏         | 34/44 [06:19<02:01, 12.18s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [06:32<01:55, 12.81s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  80%|██████████████████████████████████▏        | 35/44 [06:33<01:54, 12.67s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [06:43<01:37, 12.25s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  82%|███████████████████████████████████▏       | 36/44 [06:44<01:37, 12.15s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  84%|████████████████████████████████████▏      | 37/44 [06:54<01:23, 11.89s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  84%|████████████████████████████████████▏      | 37/44 [06:55<01:22, 11.79s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  86%|█████████████████████████████████████▏     | 38/44 [07:05<01:09, 11.63s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  86%|█████████████████████████████████████▏     | 38/44 [07:06<01:09, 11.59s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [07:19<01:01, 12.22s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  89%|██████████████████████████████████████     | 39/44 [07:20<01:00, 12.19s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [07:30<00:47, 11.92s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  91%|███████████████████████████████████████    | 40/44 [07:31<00:47, 11.92s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [07:38<00:32, 10.83s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  93%|████████████████████████████████████████   | 41/44 [07:40<00:32, 10.87s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  95%|█████████████████████████████████████████  | 42/44 [07:49<00:21, 10.86s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  95%|█████████████████████████████████████████  | 42/44 [07:51<00:21, 10.92s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  98%|██████████████████████████████████████████ | 43/44 [07:59<00:10, 10.47s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
#  98%|██████████████████████████████████████████ | 43/44 [08:00<00:10, 10.45s/it]/kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [08:10<00:00, 11.14s/it]
# __main__ - Mean SISNR is -9.632864936508916
# __main__ - Mean SISNRi is -1.6048382845791904
# __main__ - Mean SDR is -16.515790143931184
# __main__ - Mean SDRi is -50.48634807746916
# [rank0]:[W420 21:07:49.850130715 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())
# /kaggle/working/demucs-train.py:291: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(
# /kaggle/working/demucs-train.py:296: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr_baseline, _, _, _ = bss_eval_sources(
# 100%|███████████████████████████████████████████| 44/44 [08:11<00:00, 11.16s/it]

# %% [markdown]
# ## Result Decleration

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate

if result_file_path is not None:
    df = pd.read_csv(result_file_path)
else:
    # Sample data 
    data = {
        'model_name': ['demucs'],
        'batch_size': [1],
        'n_epochs': [30],
        'n_samples': [8000],
        'chunk_size': [30],
        'snt_id': [-11.316875255705217],
        'sdr': [-45.328893867866654],
        'sdr_i': [-19.785856680436567],
        'si-snr': [-14.166560108011419],
        'si-snr_i': [-14.166560108011419]
    }
    df = pd.DataFrame(data)


def create_table(df):
    
    formatted_df = df.copy()
    float_cols = df.select_dtypes(include=['float64']).columns
    formatted_df[float_cols] = formatted_df[float_cols].round(2)
    table = tabulate(formatted_df, headers='keys', tablefmt='grid', showindex=False)
    return table

def create_plots(df):
    plt.figure(figsize=(15, 8))
    
    metrics = ['sdr', 'sdr_i', 'si-snr', 'si-snr_i']
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    
    for i, metric in enumerate(metrics):
        plt.subplot(2, 2, i+1)
        plt.bar(df['model_name'], df[metric], color=colors[i])
        plt.title(f'{metric.upper()} Comparison', fontweight='bold')
        plt.ylabel('dB')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        
        for j, val in enumerate(df[metric]):
            plt.text(j, val/2, f'{val:.2f}', ha='center', color='white', fontweight='bold')
    
    plt.tight_layout()
    return plt


print("=== Formatted Table ===")
print(create_table(df))

print("\n=== Generating Plots ===")
plot = create_plots(df)
plot.show()
# Out:
# === Formatted Table ===
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | model_name   |   n_epochs |   learning_rate |   chunk_size |   sample_rate |    sdr |   sdr_i |   si-snr |   si-snr_i |
# +==============+============+=================+==============+===============+========+=========+==========+============+
# | convtasnet   |         10 |               0 |           10 |         16000 |  -6.83 |   -7.57 |    -1.19 |       0.51 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | convtasnet   |         10 |               0 |           10 |         16000 |  -6.83 |   -7.57 |    -1.19 |       0.51 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | dprnn        |         10 |               0 |           10 |         16000 |   3.3  |    2.55 |     0.19 |       1.89 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | dprnn        |         10 |               0 |           10 |         16000 |   3.3  |    2.55 |     0.19 |       1.89 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | sepformer    |         10 |               0 |           10 |         16000 |  -6.64 |   -7.38 |    -0.15 |       1.54 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | sepformer    |         10 |               0 |           10 |         16000 |  -6.64 |   -7.38 |    -0.15 |       1.54 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | demucs       |         10 |               0 |           10 |         16000 | -16.43 |  -50.4  |   -11.73 |      -3.71 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | demucs       |         10 |               0 |           10 |         16000 | -16.43 |  -50.4  |   -11.73 |      -3.71 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | convtasnet   |         20 |               0 |           10 |         16000 |  -7.59 |   -8.34 |    -0.33 |       1.36 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | convtasnet   |         20 |               0 |           10 |         16000 |  -7.59 |   -8.34 |    -0.33 |       1.36 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | dprnn        |         20 |               0 |           10 |         16000 |   4.03 |    3.28 |     1.03 |       2.73 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | dprnn        |         20 |               0 |           10 |         16000 |   4.03 |    3.28 |     1.03 |       2.73 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | sepformer    |         20 |               0 |           10 |         16000 |  -6.93 |   -7.68 |     0.05 |       1.74 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | sepformer    |         20 |               0 |           10 |         16000 |  -6.93 |   -7.68 |     0.05 |       1.74 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | demucs       |         20 |               0 |           10 |         16000 | -15.65 |  -49.62 |   -10.42 |      -2.39 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
# | demucs       |         20 |               0 |           10 |         16000 | -15.65 |  -49.62 |   -10.42 |      -2.39 |
# +--------------+------------+-----------------+--------------+---------------+--------+---------+----------+------------+
#
# === Generating Plots ===
# /tmp/ipykernel_31/2440490828.py:48: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# !zip -r kaggle_result.zip /kaggle/working/results
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/dprnn/ (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/ (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/dprnn-train.py (deflated 74%)
#   adding: kaggle/working/results/dprnn/1234/train_log.txt (deflated 82%)
#   adding: kaggle/working/results/dprnn/1234/save/ (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/ (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/counter.ckpt (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/encoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/lr_scheduler.ckpt (deflated 49%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/scaler.ckpt (deflated 60%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/optimizer.ckpt (deflated 8%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/decoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/masknet.ckpt (deflated 7%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/brain.ckpt (deflated 13%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+14-29-21+00/CKPT.yaml (deflated 5%)
#   adding: kaggle/working/results/dprnn/1234/save/audio_results/ (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/save/audio_results/item0_source1.wav (deflated 100%)
#   adding: kaggle/working/results/dprnn/1234/save/audio_results/item0_mix.wav (deflated 6%)
#   adding: kaggle/working/results/dprnn/1234/save/audio_results/item0_source2.wav (deflated 6%)
#   adding: kaggle/working/results/dprnn/1234/save/audio_results/item0_source2hat.wav (deflated 7%)
#   adding: kaggle/working/results/dprnn/1234/save/audio_results/item0_source1hat.wav (deflated 11%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/ (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/counter.ckpt (stored 0%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/encoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/lr_scheduler.ckpt (deflated 52%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/scaler.ckpt (deflated 60%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/optimizer.ckpt (deflated 8%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/decoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/masknet.ckpt (deflated 7%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/brain.ckpt (deflated 13%)
#   adding: kaggle/working/results/dprnn/1234/save/CKPT+2025-04-20+12-01-56+00/CKPT.yaml (deflated 6%)
#   adding: kaggle/working/results/dprnn/1234/log.txt (deflated 91%)
#   adding: kaggle/working/results/dprnn/1234/hyperparams.yaml (deflated 65%)
#   adding: kaggle/working/results/dprnn/1234/env.log (deflated 57%)
#   adding: kaggle/working/results/dprnn/1234/test_results.csv (deflated 52%)
#   adding: kaggle/working/results/demucs/ (stored 0%)
#   adding: kaggle/working/results/demucs/1234/ (stored 0%)
#   adding: kaggle/working/results/demucs/1234/train_log.txt (deflated 83%)
#   adding: kaggle/working/results/demucs/1234/demucs-train.py (deflated 73%)
#   adding: kaggle/working/results/demucs/1234/save/ (stored 0%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/ (stored 0%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/decoder6.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/decoder5.ckpt (deflated 8%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/encoder2.ckpt (deflated 8%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/encoder4.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/counter.ckpt (stored 0%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/scaler.ckpt (deflated 60%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/encoder5.ckpt (deflated 8%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/encoder1.ckpt (deflated 10%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/decoder3.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/optimizer.ckpt (deflated 24%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/lstm.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/encoder3.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/decoder1.ckpt (deflated 10%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/decoder2.ckpt (deflated 8%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/decoder4.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/linear.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/encoder6.ckpt (deflated 7%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/brain.ckpt (deflated 13%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/linearSeparator.ckpt (deflated 58%)
#   adding: kaggle/working/results/demucs/1234/save/CKPT+2025-04-20+20-51-24+00/CKPT.yaml (deflated 5%)
#   adding: kaggle/working/results/demucs/1234/save/audio_results/ (stored 0%)
#   adding: kaggle/working/results/demucs/1234/save/audio_results/itemtensor([0])_source2hat.wav (deflated 18%)
#   adding: kaggle/working/results/demucs/1234/save/audio_results/itemtensor([0])_mix.wav (deflated 6%)
#   adding: kaggle/working/results/demucs/1234/save/audio_results/itemtensor([0])_source1.wav (deflated 100%)
#   adding: kaggle/working/results/demucs/1234/save/audio_results/itemtensor([0])_source2.wav (deflated 6%)
#   adding: kaggle/working/results/demucs/1234/save/audio_results/itemtensor([0])_source1hat.wav (deflated 17%)
#   adding: kaggle/working/results/demucs/1234/log.txt (deflated 89%)
#   adding: kaggle/working/results/demucs/1234/hyperparams.yaml (deflated 69%)
#   adding: kaggle/working/results/demucs/1234/env.log (deflated 57%)
#   adding: kaggle/working/results/demucs/1234/test_results.csv (deflated 53%)
#   adding: kaggle/working/results/sepformer/ (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/ (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/train_log.txt (deflated 83%)
#   adding: kaggle/working/results/sepformer/1234/sepformer-train.py (deflated 74%)
#   adding: kaggle/working/results/sepformer/1234/save/ (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/ (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/counter.ckpt (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/encoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/lr_scheduler.ckpt (deflated 48%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/scaler.ckpt (deflated 60%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/optimizer.ckpt (deflated 8%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/decoder.ckpt (deflated 10%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/masknet.ckpt (deflated 8%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/brain.ckpt (deflated 13%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-43-16+00/CKPT.yaml (deflated 5%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/ (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/counter.ckpt (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/encoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/lr_scheduler.ckpt (deflated 49%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/scaler.ckpt (deflated 60%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/optimizer.ckpt (deflated 8%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/decoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/masknet.ckpt (deflated 8%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/brain.ckpt (deflated 13%)
#   adding: kaggle/working/results/sepformer/1234/save/CKPT+2025-04-20+17-08-22+00/CKPT.yaml (deflated 5%)
#   adding: kaggle/working/results/sepformer/1234/save/audio_results/ (stored 0%)
#   adding: kaggle/working/results/sepformer/1234/save/audio_results/item0_source1.wav (deflated 59%)
#   adding: kaggle/working/results/sepformer/1234/save/audio_results/item0_mix.wav (deflated 5%)
#   adding: kaggle/working/results/sepformer/1234/save/audio_results/item0_source2.wav (deflated 5%)
#   adding: kaggle/working/results/sepformer/1234/save/audio_results/item0_source2hat.wav (deflated 14%)
#   adding: kaggle/working/results/sepformer/1234/save/audio_results/item0_source1hat.wav (deflated 5%)
#   adding: kaggle/working/results/sepformer/1234/log.txt (deflated 89%)
#   adding: kaggle/working/results/sepformer/1234/hyperparams.yaml (deflated 66%)
#   adding: kaggle/working/results/sepformer/1234/env.log (deflated 57%)
#   adding: kaggle/working/results/sepformer/1234/test_results.csv (deflated 53%)
#   adding: kaggle/working/results/convtasnet/ (stored 0%)
#   adding: kaggle/working/results/convtasnet/1234/ (stored 0%)
#   adding: kaggle/working/results/convtasnet/1234/train_log.txt (deflated 83%)
#   adding: kaggle/working/results/convtasnet/1234/convtasnet-train.py (deflated 74%)
#   adding: kaggle/working/results/convtasnet/1234/save/ (stored 0%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/ (stored 0%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/counter.ckpt (stored 0%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/encoder.ckpt (deflated 11%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/lr_scheduler.ckpt (deflated 49%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/scaler.ckpt (deflated 60%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/optimizer.ckpt (deflated 8%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/decoder.ckpt (deflated 10%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/masknet.ckpt (deflated 8%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/brain.ckpt (deflated 13%)
#   adding: kaggle/working/results/convtasnet/1234/save/CKPT+2025-04-20+08-33-42+00/CKPT.yaml (deflated 5%)
#   adding: kaggle/working/results/convtasnet/1234/save/audio_results/ (stored 0%)
#   adding: kaggle/working/results/convtasnet/1234/save/audio_results/item0_source1.wav (deflated 59%)
#   adding: kaggle/working/results/convtasnet/1234/save/audio_results/item0_mix.wav (deflated 5%)
#   adding: kaggle/working/results/convtasnet/1234/save/audio_results/item0_source2.wav (deflated 5%)
#   adding: kaggle/working/results/convtasnet/1234/save/audio_results/item0_source2hat.wav (deflated 16%)
#   adding: kaggle/working/results/convtasnet/1234/save/audio_results/item0_source1hat.wav (deflated 5%)
#   adding: kaggle/working/results/convtasnet/1234/log.txt (deflated 91%)
#   adding: kaggle/working/results/convtasnet/1234/hyperparams.yaml (deflated 65%)
#   adding: kaggle/working/results/convtasnet/1234/env.log (deflated 57%)
#   adding: kaggle/working/results/convtasnet/1234/test_results.csv (deflated 53%)
